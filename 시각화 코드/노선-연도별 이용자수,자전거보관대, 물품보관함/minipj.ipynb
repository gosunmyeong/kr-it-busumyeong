# %%
import pandas as pd

# %%
one = pd.read_csv("./data/metro/data/CARD_SUBWAY_MONTH_202401.csv", index_col = "사용일자")

# %%
one
# Out:
#           노선명           역명  승차총승객수  하차총승객수      등록일자  null
# 사용일자
# 20240101  5호선          애오개    2130    2279  20240104   NaN
# 20240101  과천선       정부과천청사    3320    3414  20240104   NaN
# 20240101  과천선          인덕원    8264    8843  20240104   NaN
# 20240101  과천선           평촌    4908    4946  20240104   NaN
# 20240101  과천선           범계   10865   10892  20240104   NaN
# ...       ...          ...     ...     ...       ...   ...
# 20240131  7호선         태릉입구    8965    8450  20240203   NaN
# 20240131  7호선  공릉(서울과학기술대)   12210   12068  20240203   NaN
# 20240131  7호선           하계   19260   18086  20240203   NaN
# 20240131  7호선           중계   16251   15125  20240203   NaN
# 20240131  7호선           노원   26057   27563  20240203   NaN
#
# [19001 rows x 6 columns]

# %%
one.shape
# Out:
# (19001, 6)

# %%
one.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19001 entries, 20240101 to 20240131
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   노선명     19001 non-null  object
#  1   역명      19001 non-null  object
#  2   승차총승객수  19001 non-null  int64
#  3   하차총승객수  19001 non-null  int64
#  4   등록일자    19001 non-null  int64
#  5   null    0 non-null      float64
# dtypes: float64(1), int64(3), object(2)
# memory usage: 1.0+ MB

# %%
one
# Out:
#           노선명           역명  승차총승객수  하차총승객수      등록일자  null
# 사용일자
# 20240101  5호선          애오개    2130    2279  20240104   NaN
# 20240101  과천선       정부과천청사    3320    3414  20240104   NaN
# 20240101  과천선          인덕원    8264    8843  20240104   NaN
# 20240101  과천선           평촌    4908    4946  20240104   NaN
# 20240101  과천선           범계   10865   10892  20240104   NaN
# ...       ...          ...     ...     ...       ...   ...
# 20240131  7호선         태릉입구    8965    8450  20240203   NaN
# 20240131  7호선  공릉(서울과학기술대)   12210   12068  20240203   NaN
# 20240131  7호선           하계   19260   18086  20240203   NaN
# 20240131  7호선           중계   16251   15125  20240203   NaN
# 20240131  7호선           노원   26057   27563  20240203   NaN
#
# [19001 rows x 6 columns]

# %%
one["등록일자"].unique()
# Out:
# array([20240104, 20240105, 20240106, 20240107, 20240108, 20240109,
#        20240110, 20240111, 20240112, 20240113, 20240114, 20240115,
#        20240116, 20240117, 20240118, 20240119, 20240120, 20240121,
#        20240122, 20240123, 20240124, 20240125, 20240126, 20240127,
#        20240128, 20240129, 20240130, 20240131, 20240201, 20240202,
#        20240203], dtype=int64)

# %%
two["등록일자"].unique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[392], line 1
# ----> 1 two["등록일자"].unique()
#
# NameError: name 'two' is not defined

# %%
one = pd.read_csv("./data/metro/data/CARD_SUBWAY_MONTH_202401.csv")

# %%
two = pd.read_csv("./data/metro/data/CARD_SUBWAY_MONTH_202402.csv",encoding = "cp949", index_col = "사용일자")

# %%
two.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17807 entries, 20240201 to 20240229
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   노선명     17807 non-null  object
#  1   역명      17807 non-null  object
#  2   승차총승객수  17807 non-null  int64
#  3   하차총승객수  17807 non-null  int64
#  4   등록일자    17807 non-null  int64
# dtypes: int64(3), object(2)
# memory usage: 834.7+ KB

# %%
three.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[400], line 1
# ----> 1 three.info()
#
# NameError: name 'three' is not defined

# %%
four.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[402], line 1
# ----> 1 four.info()
#
# NameError: name 'four' is not defined

# %%
five.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[404], line 1
# ----> 1 five.info()
#
# NameError: name 'five' is not defined

# %%
six.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[406], line 1
# ----> 1 six.info()
#
# NameError: name 'six' is not defined

# %%
seven.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[408], line 1
# ----> 1 seven.info()
#
# NameError: name 'seven' is not defined

# %%
eight.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[410], line 1
# ----> 1 eight.info()
#
# NameError: name 'eight' is not defined

# %%
nine.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[412], line 1
# ----> 1 nine.info()
#
# NameError: name 'nine' is not defined

# %%
ten.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[414], line 1
# ----> 1 ten.info()
#
# NameError: name 'ten' is not defined

# %%
eleven.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18519 entries, 20241101 to 20241130
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   노선명     18519 non-null  object
#  1   역명      18519 non-null  object
#  2   승차총승객수  18519 non-null  int64
#  3   하차총승객수  18519 non-null  int64
#  4   등록일자    18519 non-null  int64
#  5   null    0 non-null      float64
# dtypes: float64(1), int64(3), object(2)
# memory usage: 1012.8+ KB

# %%
twelve.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19122 entries, 20241201 to 20241231
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   노선명     19122 non-null  object
#  1   역명      19122 non-null  object
#  2   승차총승객수  19122 non-null  int64
#  3   하차총승객수  19122 non-null  int64
#  4   등록일자    19122 non-null  int64
#  5   null    0 non-null      float64
# dtypes: float64(1), int64(3), object(2)
# memory usage: 1.0+ MB

# %%
three = pd.read_csv("./data/metro/data/CARD_SUBWAY_MONTH_202403.csv", index_col = "사용일자")

# %%
four = pd.read_csv("./data/metro/data/CARD_SUBWAY_MONTH_202404.csv", index_col = "사용일자")

# %%
five = pd.read_csv("./data/metro/data/CARD_SUBWAY_MONTH_202405.csv", index_col = "사용일자")

# %%
six = pd.read_csv("./data/metro/data/CARD_SUBWAY_MONTH_202406.csv", index_col = "사용일자")

# %%
seven = pd.read_csv("./data/metro/data/CARD_SUBWAY_MONTH_202407.csv", index_col = "사용일자")

# %%
eight = pd.read_csv("./data/metro/data/CARD_SUBWAY_MONTH_202408.csv", index_col = "사용일자")

# %%
nine = pd.read_csv("./data/metro/data/CARD_SUBWAY_MONTH_202409.csv", index_col = "사용일자")

# %%
ten = pd.read_csv("./data/metro/data/CARD_SUBWAY_MONTH_202410.csv", index_col = "사용일자")

# %%
eleven = pd.read_csv("./data/metro/data/CARD_SUBWAY_MONTH_202411.csv", index_col = "사용일자")

# %%
twelve = pd.read_csv("./data/metro/data/CARD_SUBWAY_MONTH_202412.csv", index_col = "사용일자")

# %%
CARD_SUBWAY_MONTH_2024 = pd.concat([one,two,three,four,five,six,seven,eight,nine,ten,eleven,twelve])

# %%
CARD_SUBWAY_MONTH_2024
# Out:
#           노선명        역명  승차총승객수  하차총승객수      등록일자  null
# 사용일자
# 20240101  5호선       애오개    2130    2279  20240104   NaN
# 20240101  과천선    정부과천청사    3320    3414  20240104   NaN
# 20240101  과천선       인덕원    8264    8843  20240104   NaN
# 20240101  과천선        평촌    4908    4946  20240104   NaN
# 20240101  과천선        범계   10865   10892  20240104   NaN
# ...       ...       ...     ...     ...       ...   ...
# 20241231  중앙선        중랑    5799    5330  20250103   NaN
# 20241231  중앙선        회기   26235   23257  20250103   NaN
# 20241231  장항선  신창(순천향대)    1320    1171  20250103   NaN
# 20241231  5호선       까치산   28999   26951  20250103   NaN
# 20241231  1호선       서울역   68306   65968  20250103   NaN
#
# [225512 rows x 6 columns]

# %%
CARD_SUBWAY_MONTH_2024.to_csv("./data/metro/data/CARD_SUBWAY_MONTH_2024.csv")

# %%
mon1 = pd.read_csv("./data/metro/data/CARD_SUBWAY_MONTH_202301.csv", index_col = "사용일자")

# %%
mon2 = pd.read_csv("./data/metro/data/CARD_SUBWAY_MONTH_202302.csv", index_col = "사용일자")

# %%
mon3 = pd.read_csv("./data/metro/data/CARD_SUBWAY_MONTH_202303.csv", index_col = "사용일자")

# %%
mon4 = pd.read_csv("./data/metro/data/CARD_SUBWAY_MONTH_202304.csv", index_col = "사용일자")

# %%
mon5 = pd.read_csv("./data/metro/data/CARD_SUBWAY_MONTH_202305.csv", index_col = "사용일자")

# %%
mon6 = pd.read_csv("./data/metro/data/CARD_SUBWAY_MONTH_202306.csv", index_col = "사용일자")

# %%
mon7 = pd.read_csv("./data/metro/data/CARD_SUBWAY_MONTH_202307.csv", index_col = "사용일자")

# %%
mon8 = pd.read_csv("./data/metro/data/CARD_SUBWAY_MONTH_202308.csv", index_col = "사용일자")

# %%
mon9 = pd.read_csv("./data/metro/data/CARD_SUBWAY_MONTH_202309.csv", index_col = "사용일자")

# %%
mon10 = pd.read_csv("./data/metro/data/CARD_SUBWAY_MONTH_202310.csv", index_col = "사용일자")

# %%
mon11 = pd.read_csv("./data/metro/data/CARD_SUBWAY_MONTH_202311.csv", index_col = "사용일자")

# %%
mon12 = pd.read_csv("./data/metro/data/CARD_SUBWAY_MONTH_202312.csv", index_col = "사용일자")

# %%
CARD_SUBWAY_MONTH_2023 = pd.concat([mon1,mon2,mon3,mon4,mon5,mon6,mon7,mon8,mon9,mon10,mon11,mon12])

# %%
CARD_SUBWAY_MONTH_2023.to_csv("./data/metro/data/CARD_SUBWAY_MONTH_2023.csv")

# %%
year23 = pd.read_csv("./data/metro/data/CARD_SUBWAY_MONTH_2023.csv")

# %%
year24 = pd.read_csv("./data/metro/data/CARD_SUBWAY_MONTH_2024.csv")

# %%
year19 = pd.read_csv("./data/metro/data/CARD_SUBWAY_MONTH_2019.csv", encoding = "cp949")

# %%
year20 = pd.read_csv("./data/metro/data/CARD_SUBWAY_MONTH_2020.csv", encoding = "cp949")

# %%
year21 = pd.read_csv("./data/metro/data/CARD_SUBWAY_MONTH_2021.csv", encoding = "cp949")

# %%
year22 = pd.read_csv("./data/metro/data/CARD_SUBWAY_MONTH_2022.csv", encoding = "cp949")

# %%
CARD_SUBWAY_YEAR_MONTH = pd.concat([year19,year20,year21,year22,year23,year24])

# %%
CARD_SUBWAY_YEAR_MONTH
# Out:
#             사용일자  노선명        역명   승차총승객수   하차총승객수      등록일자  null
# 0       20190101  2호선     을지로4가   3862.0   3728.0  20190104   NaN
# 1       20190101  2호선     을지로3가   8104.0   7554.0  20190104   NaN
# 2       20190101  2호선     을지로입구  22478.0  21330.0  20190104   NaN
# 3       20190101  2호선        시청   8381.0   6049.0  20190104   NaN
# 4       20190101  1호선       동묘앞   8045.0   8504.0  20190104   NaN
# ...          ...  ...       ...      ...      ...       ...   ...
# 225507  20241231  중앙선        중랑   5799.0   5330.0  20250103   NaN
# 225508  20241231  중앙선        회기  26235.0  23257.0  20250103   NaN
# 225509  20241231  장항선  신창(순천향대)   1320.0   1171.0  20250103   NaN
# 225510  20241231  5호선       까치산  28999.0  26951.0  20250103   NaN
# 225511  20241231  1호선       서울역  68306.0  65968.0  20250103   NaN
#
# [1319522 rows x 7 columns]

# %%
CARD_SUBWAY_YEAR_MONTH.to_csv("./data/metro/data/CARD_SUBWAY_YEAR_MONTH.csv")

# %%
CARD_SUBWAY_YEAR_MONTH.shape
# Out:
# (1319522, 7)

# %%
CARD_SUBWAY_YEAR_MONTH.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1319522 entries, 0 to 225511
# Data columns (total 7 columns):
#  #   Column  Non-Null Count    Dtype
# ---  ------  --------------    -----
#  0   사용일자    1319522 non-null  int64
#  1   노선명     1319522 non-null  object
#  2   역명      1319522 non-null  object
#  3   승차총승객수  1319522 non-null  float64
#  4   하차총승객수  1319522 non-null  float64
#  5   등록일자    1319522 non-null  int64
#  6   null    0 non-null        float64
# dtypes: float64(3), int64(2), object(2)
# memory usage: 80.5+ MB

# %%
CARD_SUBWAY_YEAR_MONTH["역이용자수"] = CARD_SUBWAY_YEAR_MONTH["승차총승객수"]+CARD_SUBWAY_YEAR_MONTH["하차총승객수"]

# %%
CARD_SUBWAY_YEAR_MONTH.head()
# Out:
#        사용일자  노선명     역명   승차총승객수   하차총승객수      등록일자  null    역이용자수
# 0  20190101  2호선  을지로4가   3862.0   3728.0  20190104   NaN   7590.0
# 1  20190101  2호선  을지로3가   8104.0   7554.0  20190104   NaN  15658.0
# 2  20190101  2호선  을지로입구  22478.0  21330.0  20190104   NaN  43808.0
# 3  20190101  2호선     시청   8381.0   6049.0  20190104   NaN  14430.0
# 4  20190101  1호선    동묘앞   8045.0   8504.0  20190104   NaN  16549.0

# %%
CARD_SUBWAY_YEAR_MONTH = CARD_SUBWAY_YEAR_MONTH.drop(["등록일자","null"], axis=1)

# %%
CARD_SUBWAY_YEAR_MONTH[CARD_SUBWAY_YEAR_MONTH["역명"] == "신촌"]
# Out:
#             사용일자  노선명  역명   승차총승객수   하차총승객수     역이용자수
# 46      20190101  2호선  신촌  26409.0  24861.0   51270.0
# 301     20190101  경의선  신촌    329.0    327.0     656.0
# 642     20190102  2호선  신촌  48555.0  50163.0   98718.0
# 895     20190102  경의선  신촌    904.0   1273.0    2177.0
# 1244    20190103  2호선  신촌  49497.0  50778.0  100275.0
# ...          ...  ...  ..      ...      ...       ...
# 224080  20241229  경의선  신촌    258.0    322.0     580.0
# 224327  20241230  2호선  신촌  39655.0  39924.0   79579.0
# 224676  20241230  경의선  신촌    898.0   1153.0    2051.0
# 225094  20241231  경의선  신촌    854.0   1139.0    1993.0
# 225441  20241231  2호선  신촌  39925.0  40879.0   80804.0
#
# [4384 rows x 6 columns]

# %%
CARD_SUBWAY_YEAR_MONTH[CARD_SUBWAY_YEAR_MONTH["역명"] == "신도림"]
# Out:
#             사용일자  노선명   역명   승차총승객수   하차총승객수     역이용자수
# 40      20190101  2호선  신도림  25676.0  26259.0   51935.0
# 123     20190101  경부선  신도림   1454.0   1678.0    3132.0
# 636     20190102  2호선  신도림  60759.0  59042.0  119801.0
# 719     20190102  경부선  신도림   3881.0   3886.0    7767.0
# 1238    20190103  2호선  신도림  63099.0  61549.0  124648.0
# ...          ...  ...  ...      ...      ...       ...
# 224013  20241229  경부선  신도림   2596.0   2741.0    5337.0
# 224321  20241230  2호선  신도림  51579.0  49554.0  101133.0
# 224610  20241230  경부선  신도림   4054.0   4236.0    8290.0
# 225161  20241231  경부선  신도림   3657.0   3955.0    7612.0
# 225447  20241231  2호선  신도림  50735.0  48907.0   99642.0
#
# [4384 rows x 6 columns]

# %%
CARD_SUBWAY_YEAR_MONTH[CARD_SUBWAY_YEAR_MONTH["역명"] == "공덕"]
# Out:
#              사용일자       노선명  역명   승차총승객수   하차총승객수      등록일자  null
# 303      20190101       경의선  공덕   1619.0   1346.0  20190104   NaN
# 388      20190101       5호선  공덕   4120.0   4124.0  20190104   NaN
# 436      20190101       6호선  공덕   6269.0   6249.0  20190104   NaN
# 553      20190101  공항철도 1호선  공덕   1363.0   1761.0  20190104   NaN
# 897      20190102       경의선  공덕   3853.0   3177.0  20190105   NaN
# ...           ...       ...  ..      ...      ...       ...   ...
# 1318752  20241230  공항철도 1호선  공덕   3081.0   4100.0  20250102   NaN
# 1319038  20241231  공항철도 1호선  공덕   2873.0   3836.0  20250103   NaN
# 1319102  20241231       경의선  공덕   3950.0   3156.0  20250103   NaN
# 1319310  20241231       6호선  공덕  19446.0  18562.0  20250103   NaN
# 1319362  20241231       5호선  공덕  13886.0  14684.0  20250103   NaN
#
# [8773 rows x 7 columns]

# %%
CARD_SUBWAY_YEAR_MONTH["노선명"].unique()
# Out:
# array(['2호선', '1호선', '3호선', '4호선', '경부선', '경인선', '경원선', '안산선', '과천선',
#        '분당선', '일산선', '중앙선', '장항선', '경의선', '경춘선', '수인선', '경강선', '5호선',
#        '6호선', '7호선', '8호선', '9호선', '공항철도 1호선', '9호선2~3단계', '우이신설선', '신림선',
#        '서해선'], dtype=object)

# %%
len(CARD_SUBWAY_YEAR_MONTH[CARD_SUBWAY_YEAR_MONTH["노선명"]=="9호선"]["역명"].unique())
# Out:
# 26

# %%
CARD_SUBWAY_YEAR_MONTH[CARD_SUBWAY_YEAR_MONTH["노선명"]=="9호선"]["역명"].unique()
# Out:
# array(['개화', '김포공항', '공항시장', '신방화', '마곡나루', '양천향교', '가양', '증미', '등촌',
#        '염창', '신목동', '선유도', '당산', '국회의사당', '여의도', '샛강', '노량진', '노들',
#        '흑석(중앙대입구)', '동작(현충원)', '구반포', '신반포', '고속터미널', '사평', '신논현',
#        '마곡나루(서울식물원)'], dtype=object)

# %%
CARD_SUBWAY_YEAR_MONTH[CARD_SUBWAY_YEAR_MONTH["노선명"]=="9호선2~3단계"]["역명"].unique()
# Out:
# array(['언주', '선정릉', '삼성중앙', '봉은사', '종합운동장', '삼전', '석촌고분', '석촌', '송파나루',
#        '한성백제', '올림픽공원(한국체대)', '둔촌오륜', '중앙보훈병원'], dtype=object)

# %%
CARD_SUBWAY_YEAR_MONTH[CARD_SUBWAY_YEAR_MONTH["역명"] == "상봉(시외터미널)"]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, 사용일자, 노선명, 역명, 승차총승객수, 하차총승객수, 등록일자, null]
# Index: []

# %%
CARD_SUBWAY_YEAR_MONTH = pd.read_csv("./data/metro/data/CARD_SUBWAY_YEAR_MONTH.csv")

# %%
CARD_SUBWAY_YEAR_MONTH.to_csv("./data/metro/data/역이용자수.csv")

# %%
CARD_SUBWAY_YEAR_MONTH[CARD_SUBWAY_YEAR_MONTH["역명"] == "마곡나루(서울식물원)"]
# Out:
#          Unnamed: 0      사용일자       노선명           역명   승차총승객수   하차총승객수  \
# 257636        41867  20200311       9호선  마곡나루(서울식물원)   8402.0   8387.0
# 257661        41892  20200311  공항철도 1호선  마곡나루(서울식물원)   5922.0   5462.0
# 258207        42438  20200312       9호선  마곡나루(서울식물원)   8266.0   8178.0
# 258232        42463  20200312  공항철도 1호선  마곡나루(서울식물원)   5942.0   5468.0
# 258798        43029  20200313       9호선  마곡나루(서울식물원)   8322.0   8472.0
# ...             ...       ...       ...          ...      ...      ...
# 1318160      224150  20241229  공항철도 1호선  마곡나루(서울식물원)   3415.0   3850.0
# 1318568      224558  20241230       9호선  마곡나루(서울식물원)  13857.0  13750.0
# 1318755      224745  20241230  공항철도 1호선  마곡나루(서울식물원)   9037.0   9579.0
# 1319035      225025  20241231  공항철도 1호선  마곡나루(서울식물원)   8607.0   8971.0
# 1319223      225213  20241231       9호선  마곡나루(서울식물원)  13482.0  13258.0
#
#            역이용자수
# 257636   16789.0
# 257661   11384.0
# 258207   16444.0
# 258232   11410.0
# 258798   16794.0
# ...

# %%
CARD_SUBWAY_YEAR_MONTH[CARD_SUBWAY_YEAR_MONTH["역명"] == "마곡나루"]
# Out:
#         Unnamed: 0      사용일자       노선명    역명  승차총승객수  하차총승객수    역이용자수
# 531            531  20190101       9호선  마곡나루  3798.0  4056.0   7854.0
# 556            556  20190101  공항철도 1호선  마곡나루  1172.0  1464.0   2636.0
# 1123          1123  20190102       9호선  마곡나루  9459.0  9411.0  18870.0
# 1148          1148  20190102  공항철도 1호선  마곡나루  5300.0  4648.0   9948.0
# 1727          1727  20190103       9호선  마곡나루  9930.0  9861.0  19791.0
# ...            ...       ...       ...   ...     ...     ...      ...
# 255874       40105  20200308  공항철도 1호선  마곡나루  1075.0  1147.0   2222.0
# 256439       40670  20200309       9호선  마곡나루  8365.0  8550.0  16915.0
# 256464       40695  20200309  공항철도 1호선  마곡나루  6057.0  5605.0  11662.0
# 257029       41260  20200310       9호선  마곡나루  8139.0  8169.0  16308.0
# 257054       41285  20200310  공항철도 1호선  마곡나루  5787.0  5235.0  11022.0
#
# [870 rows x 7 columns]

# %%
len(CARD_SUBWAY_YEAR_MONTH[CARD_SUBWAY_YEAR_MONTH["노선명"]=="2호선"]["역명"].unique())
# Out:
# 52

# %%
CARD_SUBWAY_YEAR_MONTH[CARD_SUBWAY_YEAR_MONTH["노선명"]=="5호선"]["역명"].unique()
# Out:
# array(['방화', '개화산', '김포공항', '송정', '마곡', '발산', '우장산', '화곡', '까치산',
#        '신정(은행정)', '목동', '오목교(목동운동장앞)', '양평', '영등포구청', '영등포시장', '신길',
#        '여의도', '여의나루', '마포', '공덕', '애오개', '충정로(경기대입구)', '서대문',
#        '광화문(세종문화회관)', '종로3가', '을지로4가', '동대문역사문화공원', '청구', '신금호', '행당',
#        '왕십리(성동구청)', '마장', '답십리', '장한평', '군자(능동)', '아차산(어린이대공원후문)',
#        '광나루(장신대)', '천호(풍납토성)', '강동', '길동', '굽은다리(강동구민회관앞)', '명일', '고덕',
#        '상일동', '둔촌동', '올림픽공원(한국체대)', '방이', '오금', '개롱', '거여', '마천',
#        '동대문역사문화공원(DDP)', '미사', '하남풍산', '하남검단산', '하남시청(덕풍·신장)', '강일'],
#       dtype=object)

# %%
CARD_SUBWAY_YEAR_MONTH[CARD_SUBWAY_YEAR_MONTH["노선명"]=="2호선"]["역명"].unique()
# Out:
# array(['을지로4가', '을지로3가', '을지로입구', '시청', '동대문역사문화공원', '신당', '상왕십리',
#        '왕십리(성동구청)', '한양대', '뚝섬', '성수', '건대입구', '구의(광진구청)', '강변(동서울터미널)',
#        '잠실나루', '잠실(송파구청)', '잠실새내', '종합운동장', '삼성(무역센터)', '선릉', '역삼', '강남',
#        '교대(법원.검찰청)', '서초', '방배', '사당', '낙성대', '서울대입구(관악구청)', '봉천', '신림',
#        '신대방', '구로디지털단지', '대림(구로구청)', '신도림', '문래', '영등포구청', '당산', '합정',
#        '홍대입구', '신촌', '이대', '아현', '충정로(경기대입구)', '용답', '신답', '신설동', '도림천',
#        '양천구청', '신정네거리', '용두(동대문구청)', '동대문역사문화공원(DDP)', '낙성대(강감찬)'],
#       dtype=object)

# %%
CARD_SUBWAY_YEAR_MONTH[CARD_SUBWAY_YEAR_MONTH["노선명"]=="3호선"]["역명"].unique()
# Out:
# array(['지축', '구파발', '연신내', '불광', '녹번', '홍제', '무악재', '독립문', '경복궁(정부서울청사)',
#        '안국', '종로3가', '을지로3가', '충무로', '동대입구', '약수', '금호', '옥수', '압구정',
#        '신사', '잠원', '고속터미널', '교대(법원.검찰청)', '남부터미널(예술의전당)', '양재(서초구청)',
#        '매봉', '도곡', '대치', '학여울', '대청', '일원', '수서', '가락시장', '경찰병원', '오금'],
#       dtype=object)

# %%
len(CARD_SUBWAY_YEAR_MONTH[CARD_SUBWAY_YEAR_MONTH["노선명"]=="3호선"]["역명"].unique())
# Out:
# 34

# %%
CARD_SUBWAY_YEAR_MONTH[CARD_SUBWAY_YEAR_MONTH["노선명"]=="4호선"]["역명"].unique()
# Out:
# array(['당고개', '상계', '노원', '창동', '쌍문', '수유(강북구청)', '미아(서울사이버대학)', '미아사거리',
#        '길음', '성신여대입구(돈암)', '한성대입구(삼선교)', '혜화', '동대문', '동대문역사문화공원', '충무로',
#        '명동', '회현(남대문시장)', '서울역', '숙대입구(갈월)', '삼각지', '신용산', '이촌(국립중앙박물관)',
#        '동작(현충원)', '총신대입구(이수)', '사당', '남태령', '동대문역사문화공원(DDP)'],
#       dtype=object)

# %%
len(CARD_SUBWAY_YEAR_MONTH[CARD_SUBWAY_YEAR_MONTH["노선명"]=="4호선"]["역명"].unique())
# Out:
# 27

# %%
CARD_SUBWAY_YEAR_MONTH[CARD_SUBWAY_YEAR_MONTH["노선명"]=="5호선"]["역명"].unique()
# Out:
# array(['방화', '개화산', '김포공항', '송정', '마곡', '발산', '우장산', '화곡', '까치산',
#        '신정(은행정)', '목동', '오목교(목동운동장앞)', '양평', '영등포구청', '영등포시장', '신길',
#        '여의도', '여의나루', '마포', '공덕', '애오개', '충정로(경기대입구)', '서대문',
#        '광화문(세종문화회관)', '종로3가', '을지로4가', '동대문역사문화공원', '청구', '신금호', '행당',
#        '왕십리(성동구청)', '마장', '답십리', '장한평', '군자(능동)', '아차산(어린이대공원후문)',
#        '광나루(장신대)', '천호(풍납토성)', '강동', '길동', '굽은다리(강동구민회관앞)', '명일', '고덕',
#        '상일동', '둔촌동', '올림픽공원(한국체대)', '방이', '오금', '개롱', '거여', '마천',
#        '동대문역사문화공원(DDP)', '미사', '하남풍산', '하남검단산', '하남시청(덕풍·신장)', '강일'],
#       dtype=object)

# %%
len(CARD_SUBWAY_YEAR_MONTH[CARD_SUBWAY_YEAR_MONTH["노선명"]=="5호선"]["역명"].unique())
# Out:
# 57

# %%
CARD_SUBWAY_YEAR_MONTH[CARD_SUBWAY_YEAR_MONTH["노선명"]=="6호선"]["역명"].unique()
# Out:
# array(['응암', '역촌', '불광', '독바위', '연신내', '구산', '새절(신사)', '증산(명지대앞)',
#        '디지털미디어시티', '월드컵경기장(성산)', '마포구청', '망원', '합정', '상수', '광흥창(서강)',
#        '대흥(서강대앞)', '공덕', '효창공원앞', '삼각지', '녹사평(용산구청)', '이태원', '한강진',
#        '버티고개', '약수', '청구', '신당', '동묘앞', '창신', '보문', '안암(고대병원앞)',
#        '고려대(종암)', '월곡(동덕여대)', '상월곡(한국과학기술연구원)', '돌곶이', '석계', '태릉입구',
#        '화랑대(서울여대입구)', '봉화산(서울의료원)', '신내'], dtype=object)

# %%
len(CARD_SUBWAY_YEAR_MONTH[CARD_SUBWAY_YEAR_MONTH["노선명"]=="6호선"]["역명"].unique())
# Out:
# 39

# %%
CARD_SUBWAY_YEAR_MONTH[CARD_SUBWAY_YEAR_MONTH["노선명"]=="7호선"]["역명"].unique()
# Out:
# array(['장암', '도봉산', '수락산', '마들', '노원', '중계', '하계', '공릉(서울과학기술대)', '태릉입구',
#        '먹골', '중화', '상봉(시외버스터미널)', '면목', '사가정', '용마산', '중곡', '군자(능동)',
#        '어린이대공원(세종대)', '건대입구', '뚝섬유원지', '청담', '강남구청', '학동', '논현', '반포',
#        '고속터미널', '내방', '이수', '남성', '숭실대입구(살피재)', '상도', '장승배기', '신대방삼거리',
#        '보라매', '신풍', '대림(구로구청)', '남구로', '가산디지털단지', '철산', '광명사거리', '천왕',
#        '온수(성공회대입구)', '까치울', '부천종합운동장', '춘의', '신중동', '부천시청', '상동', '삼산체육관',
#        '굴포천', '부평구청', '용마산(용마폭포공원)', '상봉', '자양(뚝섬한강공원)'], dtype=object)

# %%
CARD_SUBWAY_YEAR_MONTH[CARD_SUBWAY_YEAR_MONTH["역명"]=="상봉(시외버스터미널)"]
# Out:
#          Unnamed: 0      사용일자  노선명           역명   승차총승객수   하차총승객수      등록일자  \
# 273             273  20190101  중앙선  상봉(시외버스터미널)   3227.0   3105.0  20190104
# 469             469  20190101  7호선  상봉(시외버스터미널)   8113.0   7792.0  20190104
# 869             869  20190102  중앙선  상봉(시외버스터미널)   5958.0   5682.0  20190105
# 1063           1063  20190102  7호선  상봉(시외버스터미널)  18054.0  17197.0  20190105
# 1472           1472  20190103  중앙선  상봉(시외버스터미널)   6202.0   5824.0  20190106
# ...             ...       ...  ...          ...      ...      ...       ...
# 1100662        6652  20240111  중앙선  상봉(시외버스터미널)   5951.0   5868.0  20240114
# 1100789        6779  20240112  중앙선  상봉(시외버스터미널)   6415.0   6179.0  20240115
# 1101141        7131  20240112  7호선  상봉(시외버스터미널)  19415.0  18797.0  20240115
# 1101587        7577  20240113  7호선  상봉(시외버스터미널)  15379.0  15015.0  20240116
# 1101954        7944  20240113  중앙선  상봉(시외버스터미널)   5073.0   5069.0  20240116
#
#          null
# 273       NaN
# 469       NaN
# ...

# %%
len(CARD_SUBWAY_YEAR_MONTH[CARD_SUBWAY_YEAR_MONTH["노선명"]=="7호선"]["역명"].unique())
# Out:
# 54

# %%
CARD_SUBWAY_YEAR_MONTH[CARD_SUBWAY_YEAR_MONTH["노선명"]=="8호선"]["역명"].unique()
# Out:
# array(['암사', '천호(풍납토성)', '강동구청', '몽촌토성(평화의문)', '잠실(송파구청)', '석촌', '송파',
#        '가락시장', '문정', '장지', '복정', '산성', '남한산성입구(성남법원.검찰청)', '단대오거리', '신흥',
#        '수진', '모란', '남위례', '암사역사공원'], dtype=object)

# %%
len(CARD_SUBWAY_YEAR_MONTH[CARD_SUBWAY_YEAR_MONTH["노선명"]=="8호선"]["역명"].unique())
# Out:
# 19

# %%
CARD_SUBWAY_YEAR_MONTH = CARD_SUBWAY_YEAR_MONTH.drop("Unnamed: 0", axis=1)

# %%
CARD_SUBWAY_YEAR_MONTH
# Out:
#              사용일자  노선명        역명   승차총승객수   하차총승객수      등록일자  null
# 0        20190101  2호선     을지로4가   3862.0   3728.0  20190104   NaN
# 1        20190101  2호선     을지로3가   8104.0   7554.0  20190104   NaN
# 2        20190101  2호선     을지로입구  22478.0  21330.0  20190104   NaN
# 3        20190101  2호선        시청   8381.0   6049.0  20190104   NaN
# 4        20190101  1호선       동묘앞   8045.0   8504.0  20190104   NaN
# ...           ...  ...       ...      ...      ...       ...   ...
# 1319517  20241231  중앙선        중랑   5799.0   5330.0  20250103   NaN
# 1319518  20241231  중앙선        회기  26235.0  23257.0  20250103   NaN
# 1319519  20241231  장항선  신창(순천향대)   1320.0   1171.0  20250103   NaN
# 1319520  20241231  5호선       까치산  28999.0  26951.0  20250103   NaN
# 1319521  20241231  1호선       서울역  68306.0  65968.0  20250103   NaN
#
# [1319522 rows x 7 columns]

# %%
CARD_SUBWAY_YEAR_MONTH[CARD_SUBWAY_YEAR_MONTH["역명"] == "암사"]
# Out:
#              사용일자  노선명  역명   승차총승객수   하차총승객수      등록일자  null
# 509      20190101  8호선  암사   7919.0   7865.0  20190104   NaN
# 1103     20190102  8호선  암사  20643.0  18042.0  20190105   NaN
# 1706     20190103  8호선  암사  21028.0  18606.0  20190106   NaN
# 2285     20190104  8호선  암사  21789.0  19100.0  20190107   NaN
# 2890     20190105  8호선  암사  14388.0  13030.0  20190108   NaN
# ...           ...  ...  ..      ...      ...       ...   ...
# 1316796  20241227  8호선  암사  17932.0  16458.0  20241230   NaN
# 1317326  20241228  8호선  암사  12549.0  11673.0  20241231   NaN
# 1317950  20241229  8호선  암사   8956.0   8553.0  20250101   NaN
# 1318546  20241230  8호선  암사  17147.0  15922.0  20250102   NaN
# 1319245  20241231  8호선  암사  17141.0  15625.0  20250103   NaN
#
# [2192 rows x 7 columns]

# %%
CARD_SUBWAY_YEAR_MONTH[CARD_SUBWAY_YEAR_MONTH["역명"] == "암사역사공원"]
# Out:
#              사용일자  노선명      역명  승차총승객수  하차총승객수      등록일자  null
# 1230993  20240810  8호선  암사역사공원  5086.0  5035.0  20240813   NaN
# 1231606  20240811  8호선  암사역사공원  3207.0  3065.0  20240814   NaN
# 1232182  20240812  8호선  암사역사공원  4979.0  5038.0  20240815   NaN
# 1232742  20240813  8호선  암사역사공원  5025.0  4664.0  20240816   NaN
# 1233463  20240814  8호선  암사역사공원  5080.0  4702.0  20240817   NaN
# ...           ...  ...     ...     ...     ...       ...   ...
# 1316797  20241227  8호선  암사역사공원  6328.0  5540.0  20241230   NaN
# 1317325  20241228  8호선  암사역사공원  4032.0  3468.0  20241231   NaN
# 1317949  20241229  8호선  암사역사공원  2911.0  2781.0  20250101   NaN
# 1318545  20241230  8호선  암사역사공원  6013.0  5221.0  20250102   NaN
# 1319246  20241231  8호선  암사역사공원  5732.0  4908.0  20250103   NaN
#
# [144 rows x 7 columns]

# %%
CARD_SUBWAY_YEAR_MONTH[CARD_SUBWAY_YEAR_MONTH["노선명"]=="1호선"]["역명"].unique()
# Out:
# array(['동묘앞', '청량리(서울시립대입구)', '제기동', '신설동', '동대문', '종로5가', '종각', '서울역',
#        '시청', '종로3가'], dtype=object)

# %%
CARD_SUBWAY_YEAR_MONTH["노선명"].unique()
# Out:
# array(['2호선', '1호선', '3호선', '4호선', '경부선', '경인선', '경원선', '안산선', '과천선',
#        '분당선', '일산선', '중앙선', '장항선', '경의선', '경춘선', '수인선', '경강선', '5호선',
#        '6호선', '7호선', '8호선', '9호선', '공항철도 1호선', '9호선2~3단계', '우이신설선', '신림선',
#        '서해선'], dtype=object)

# %%
CARD_SUBWAY_YEAR_MONTH[CARD_SUBWAY_YEAR_MONTH["노선명"]=="경부선"]["역명"].unique()
# Out:
# array(['서울역', '남영', '용산', '노량진', '대방', '영등포', '신도림', '신길', '구로',
#        '가산디지털단지', '금천구청', '석수', '관악', '안양', '명학', '금정', '군포', '의왕',
#        '성균관대', '화서', '수원', '독산', '세류', '병점', '세마', '오산대', '오산', '진위',
#        '송탄', '서정리', '지제', '평택', '성환', '직산', '두정', '천안', '당정', '서동탄', '광명',
#        '평택지제'], dtype=object)

# %%
CARD_SUBWAY_YEAR_MONTH[CARD_SUBWAY_YEAR_MONTH["노선명"]=="경원선"]["역명"].unique()
# Out:
# array(['이촌(국립중앙박물관)', '서빙고', '한남', '옥수', '응봉', '왕십리(성동구청)',
#        '청량리(서울시립대입구)', '외대앞', '신이문', '석계', '광운대', '월계', '녹천', '창동', '방학',
#        '도봉', '도봉산', '망월사', '회룡', '의정부', '가능', '녹양', '양주', '덕계', '덕정',
#        '지행', '동두천중앙', '보산', '동두천', '소요산', '연천', '전곡', '초성리', '청산'],
#       dtype=object)

# %%
CARD_SUBWAY_YEAR_MONTH[CARD_SUBWAY_YEAR_MONTH["노선명"]=="경인선"]["역명"].unique()
# Out:
# array(['개봉', '오류동', '역곡', '부천', '송내', '부평', '백운', '동암', '주안', '제물포',
#        '동인천', '인천', '구일', '소사', '부개', '간석', '도원', '온수(성공회대입구)', '중동',
#        '도화'], dtype=object)

# %%
CARD_SUBWAY_YEAR_MONTH[CARD_SUBWAY_YEAR_MONTH["노선명"]=="경의선"]["역명"].unique()
# Out:
# array(['서울역', '신촌', '효창공원앞', '공덕', '서강대', '홍대입구', '가좌', '디지털미디어시티', '수색',
#        '화전', '강매', '행신', '능곡', '곡산', '백마', '풍산', '일산', '탄현', '야당', '운정',
#        '금릉', '금촌', '월롱', '파주', '문산', '계양', '김포공항', '검암', '임진강', '운천',
#        '한국항공대'], dtype=object)

# %%
CARD_SUBWAY_YEAR_MONTH[CARD_SUBWAY_YEAR_MONTH["노선명"]=="4호선"]["역명"].unique()
# Out:
# array(['당고개', '상계', '노원', '창동', '쌍문', '수유(강북구청)', '미아(서울사이버대학)', '미아사거리',
#        '길음', '성신여대입구(돈암)', '한성대입구(삼선교)', '혜화', '동대문', '동대문역사문화공원', '충무로',
#        '명동', '회현(남대문시장)', '서울역', '숙대입구(갈월)', '삼각지', '신용산', '이촌(국립중앙박물관)',
#        '동작(현충원)', '총신대입구(이수)', '사당', '남태령', '동대문역사문화공원(DDP)'],
#       dtype=object)

# %%
CARD_SUBWAY_YEAR_MONTH[CARD_SUBWAY_YEAR_MONTH["역명"]=="회기"]
# Out:
#              사용일자  노선명  역명   승차총승객수   하차총승객수      등록일자  null
# 271      20190101  중앙선  회기  12769.0  13842.0  20190104   NaN
# 867      20190102  중앙선  회기  26769.0  27064.0  20190105   NaN
# 1470     20190103  중앙선  회기  27940.0  27770.0  20190106   NaN
# 2052     20190104  중앙선  회기  29757.0  29092.0  20190107   NaN
# 2655     20190105  중앙선  회기  26220.0  25362.0  20190108   NaN
# ...           ...  ...  ..      ...      ...       ...   ...
# 1316494  20241227  중앙선  회기  27131.0  24958.0  20241230   NaN
# 1317670  20241228  중앙선  회기  24046.0  22054.0  20241231   NaN
# 1318289  20241229  중앙선  회기  16522.0  16320.0  20250101   NaN
# 1318884  20241230  중앙선  회기  25793.0  24300.0  20250102   NaN
# 1319518  20241231  중앙선  회기  26235.0  23257.0  20250103   NaN
#
# [2192 rows x 7 columns]

# %%
CARD_SUBWAY_YEAR_MONTH[CARD_SUBWAY_YEAR_MONTH["노선명"]=="중앙선"]["역명"].unique()
# Out:
# array(['회기', '중랑', '상봉(시외버스터미널)', '망우', '양원', '구리', '도농', '양정', '덕소',
#        '도심', '팔당', '운길산', '양수', '신원', '국수', '아신', '오빈', '양평', '원덕', '용문',
#        '지평', '상봉'], dtype=object)

# %%
CARD_SUBWAY_YEAR_MONTH
# Out:
#              사용일자  노선명        역명   승차총승객수   하차총승객수      등록일자  null
# 0        20190101  2호선     을지로4가   3862.0   3728.0  20190104   NaN
# 1        20190101  2호선     을지로3가   8104.0   7554.0  20190104   NaN
# 2        20190101  2호선     을지로입구  22478.0  21330.0  20190104   NaN
# 3        20190101  2호선        시청   8381.0   6049.0  20190104   NaN
# 4        20190101  1호선       동묘앞   8045.0   8504.0  20190104   NaN
# ...           ...  ...       ...      ...      ...       ...   ...
# 1319517  20241231  중앙선        중랑   5799.0   5330.0  20250103   NaN
# 1319518  20241231  중앙선        회기  26235.0  23257.0  20250103   NaN
# 1319519  20241231  장항선  신창(순천향대)   1320.0   1171.0  20250103   NaN
# 1319520  20241231  5호선       까치산  28999.0  26951.0  20250103   NaN
# 1319521  20241231  1호선       서울역  68306.0  65968.0  20250103   NaN
#
# [1319522 rows x 7 columns]

# %%
aa = pd.read_csv("./data/metro/data/역이용자수.csv")

# %%
aa
# Out:
#          Unnamed: 0.1  Unnamed: 0      사용일자  노선명        역명   승차총승객수   하차총승객수  \
# 0                   0           0  20190101  2호선     을지로4가   3862.0   3728.0
# 1                   1           1  20190101  2호선     을지로3가   8104.0   7554.0
# 2                   2           2  20190101  2호선     을지로입구  22478.0  21330.0
# 3                   3           3  20190101  2호선        시청   8381.0   6049.0
# 4                   4           4  20190101  1호선       동묘앞   8045.0   8504.0
# ...               ...         ...       ...  ...       ...      ...      ...
# 1319517       1319517      225507  20241231  중앙선        중랑   5799.0   5330.0
# 1319518       1319518      225508  20241231  중앙선        회기  26235.0  23257.0
# 1319519       1319519      225509  20241231  장항선  신창(순천향대)   1320.0   1171.0
# 1319520       1319520      225510  20241231  5호선       까치산  28999.0  26951.0
# 1319521       1319521      225511  20241231  1호선       서울역  68306.0  65968.0
#
#             역이용자수
# 0          7590.0
# ...

# %%
aa = aa.drop("Unnamed: 0.1",axis = 1)

# %%
aa = aa.drop("Unnamed: 0",axis = 1)

# %%
aa.to_csv("./data/metro/data/총이용자수(연습용).csv", index = False, encoding = "utf-8-sig")

# %%
test = pd.read_csv("./data/metro/data/총이용자수(연습용).csv")

# %%
test["노선명"].unique()
# Out:
# array(['2호선', '1호선', '3호선', '4호선', '경부선', '경인선', '경원선', '안산선', '과천선',
#        '분당선', '일산선', '중앙선', '장항선', '경의선', '경춘선', '수인선', '경강선', '5호선',
#        '6호선', '7호선', '8호선', '9호선', '공항철도 1호선', '9호선2~3단계', '우이신설선', '신림선',
#        '서해선'], dtype=object)

# %%
test[test["노선명"] == '안산선', '과천선','분당선', '일산선', '장항선', '경의선', '경춘선', '수인선', '경강선', '공항철도 1호선', '우이신설선', '신림선','서해선']

# %%
test.drop(,axis=0)
# Out:
#   Cell In[113], line 1
#     test[test["노선명"] == "안산선"].drop(:,axis=0)
#                                     ^
# SyntaxError: invalid syntax

# %%
test_no_안산 = test.drop(test[test["노선명"] == "안산선"].index)

# %%
test_no_안산[test_no_안산["노선명"]== "안산역"]
# Out:
# Empty DataFrame
# Columns: [사용일자, 노선명, 역명, 승차총승객수, 하차총승객수, 역이용자수]
# Index: []

# %%
test1 = test1.drop(test[(test["노선명"] == '안산선') | (test["노선명"] == '과천선') | (test["노선명"] == '분당선') | (test["노선명"] == '일산선')].index)

# %%
test2 = test1.drop(test1[(test1["노선명"] == '장항선') | (test1["노선명"] == '경의선') | (test1["노선명"] == '경춘선') | (test1["노선명"] == '수인선') | (test1["노선명"] == '경강선') | (test1["노선명"] == '공항철도 1호선') | (test1["노선명"] == '우이신설선') | (test1["노선명"] == '신림선') | (test1["노선명"] == '서해선')].index)

# %%
test2["노선명"].unique()
# Out:
# array(['2호선', '1호선', '3호선', '4호선', '경부선', '경인선', '경원선', '중앙선', '5호선',
#        '6호선', '7호선', '8호선', '9호선', '9호선2~3단계'], dtype=object)

# %%
test2[test2["노선명"] == "9호선"]
# Out:
#              사용일자  노선명           역명   승차총승객수   하차총승객수    역이용자수
# 527      20190101  9호선           개화   2241.0   2029.0   4270.0
# 528      20190101  9호선         김포공항   7448.0   8746.0  16194.0
# 529      20190101  9호선         공항시장   1441.0   1696.0   3137.0
# 530      20190101  9호선          신방화   3253.0   3388.0   6641.0
# 531      20190101  9호선         마곡나루   3798.0   4056.0   7854.0
# ...           ...  ...          ...      ...      ...      ...
# 1319223  20241231  9호선  마곡나루(서울식물원)  13482.0  13258.0  26740.0
# 1319224  20241231  9호선          신방화   7293.0   7003.0  14296.0
# 1319225  20241231  9호선         공항시장   3292.0   3381.0   6673.0
# 1319226  20241231  9호선         김포공항   6551.0  10674.0  17225.0
# 1319227  20241231  9호선           개화   2550.0   1764.0   4314.0
#
# [54800 rows x 6 columns]

# %%
test2[test2["노선명"] == "9호선"]["역명"].unique()
# Out:
# array(['개화', '김포공항', '공항시장', '신방화', '마곡나루', '양천향교', '가양', '증미', '등촌',
#        '염창', '신목동', '선유도', '당산', '국회의사당', '여의도', '샛강', '노량진', '노들',
#        '흑석(중앙대입구)', '동작(현충원)', '구반포', '신반포', '고속터미널', '사평', '신논현',
#        '마곡나루(서울식물원)'], dtype=object)

# %%
test2[test2["노선명"] == "9호선2~3단계"]
# Out:
#              사용일자       노선명     역명   승차총승객수   하차총승객수    역이용자수
# 566      20190101  9호선2~3단계     언주   2900.0   2667.0   5567.0
# 567      20190101  9호선2~3단계    선정릉   2035.0   2334.0   4369.0
# 568      20190101  9호선2~3단계   삼성중앙   1479.0   1602.0   3081.0
# 569      20190101  9호선2~3단계    봉은사   9052.0   8309.0  17361.0
# 570      20190101  9호선2~3단계  종합운동장   1785.0   1629.0   3414.0
# ...           ...       ...    ...      ...      ...      ...
# 1319198  20241231  9호선2~3단계  종합운동장   4600.0   4700.0   9300.0
# 1319199  20241231  9호선2~3단계    봉은사  21105.0  21975.0  43080.0
# 1319200  20241231  9호선2~3단계   삼성중앙   7497.0   7615.0  15112.0
# 1319201  20241231  9호선2~3단계    선정릉   9246.0   9812.0  19058.0
# 1319202  20241231  9호선2~3단계     언주  10457.0  10404.0  20861.0
#
# [28496 rows x 6 columns]

# %%
test2[test2["노선명"] == "9호선2~3단계"]["역명"].unique()
# Out:
# array(['언주', '선정릉', '삼성중앙', '봉은사', '종합운동장', '삼전', '석촌고분', '석촌', '송파나루',
#        '한성백제', '올림픽공원(한국체대)', '둔촌오륜', '중앙보훈병원'], dtype=object)

# %%
test2[test2["노선명"] == "9호선2~3단계"]
# Out:
#              사용일자       노선명     역명   승차총승객수   하차총승객수    역이용자수
# 566      20190101  9호선2~3단계     언주   2900.0   2667.0   5567.0
# 567      20190101  9호선2~3단계    선정릉   2035.0   2334.0   4369.0
# 568      20190101  9호선2~3단계   삼성중앙   1479.0   1602.0   3081.0
# 569      20190101  9호선2~3단계    봉은사   9052.0   8309.0  17361.0
# 570      20190101  9호선2~3단계  종합운동장   1785.0   1629.0   3414.0
# ...           ...       ...    ...      ...      ...      ...
# 1319198  20241231  9호선2~3단계  종합운동장   4600.0   4700.0   9300.0
# 1319199  20241231  9호선2~3단계    봉은사  21105.0  21975.0  43080.0
# 1319200  20241231  9호선2~3단계   삼성중앙   7497.0   7615.0  15112.0
# 1319201  20241231  9호선2~3단계    선정릉   9246.0   9812.0  19058.0
# 1319202  20241231  9호선2~3단계     언주  10457.0  10404.0  20861.0
#
# [28496 rows x 6 columns]

# %%
test3 = test2.replace("9호선2~3단계","9호선")

# %%
test3[test3["노선명"] == "9호선"]["역명"].unique()
# Out:
# array(['개화', '김포공항', '공항시장', '신방화', '마곡나루', '양천향교', '가양', '증미', '등촌',
#        '염창', '신목동', '선유도', '당산', '국회의사당', '여의도', '샛강', '노량진', '노들',
#        '흑석(중앙대입구)', '동작(현충원)', '구반포', '신반포', '고속터미널', '사평', '신논현', '언주',
#        '선정릉', '삼성중앙', '봉은사', '종합운동장', '삼전', '석촌고분', '석촌', '송파나루', '한성백제',
#        '올림픽공원(한국체대)', '둔촌오륜', '중앙보훈병원'], dtype=object)

# %%
test3 = test3.replace("마곡나루(서울식물원)","마곡나루")

# %%
test2[test2["역명"] == "마곡나루"]
# Out:
#             사용일자  노선명    역명   승차총승객수   하차총승객수    역이용자수
# 531     20190101  9호선  마곡나루   3798.0   4056.0   7854.0
# 1123    20190102  9호선  마곡나루   9459.0   9411.0  18870.0
# 1727    20190103  9호선  마곡나루   9930.0   9861.0  19791.0
# 2306    20190104  9호선  마곡나루  10350.0  10280.0  20630.0
# 2911    20190105  9호선  마곡나루   7701.0   7262.0  14963.0
# ...          ...  ...   ...      ...      ...      ...
# 254673  20200306  9호선  마곡나루   8307.0   8475.0  16782.0
# 255261  20200307  9호선  마곡나루   4685.0   4651.0   9336.0
# 255849  20200308  9호선  마곡나루   3220.0   3317.0   6537.0
# 256439  20200309  9호선  마곡나루   8365.0   8550.0  16915.0
# 257029  20200310  9호선  마곡나루   8139.0   8169.0  16308.0
#
# [435 rows x 6 columns]

# %%
test2[test2["역명"] == "마곡나루(서울식물원)"]
# Out:
#              사용일자  노선명           역명   승차총승객수   하차총승객수    역이용자수
# 257636   20200311  9호선  마곡나루(서울식물원)   8402.0   8387.0  16789.0
# 258207   20200312  9호선  마곡나루(서울식물원)   8266.0   8178.0  16444.0
# 258798   20200313  9호선  마곡나루(서울식물원)   8322.0   8472.0  16794.0
# 259387   20200314  9호선  마곡나루(서울식물원)   4722.0   4799.0   9521.0
# 259975   20200315  9호선  마곡나루(서울식물원)   3046.0   3011.0   6057.0
# ...           ...  ...          ...      ...      ...      ...
# 1316774  20241227  9호선  마곡나루(서울식물원)  15056.0  14862.0  29918.0
# 1317348  20241228  9호선  마곡나루(서울식물원)   9692.0   9536.0  19228.0
# 1317972  20241229  9호선  마곡나루(서울식물원)   6835.0   6601.0  13436.0
# 1318568  20241230  9호선  마곡나루(서울식물원)  13857.0  13750.0  27607.0
# 1319223  20241231  9호선  마곡나루(서울식물원)  13482.0  13258.0  26740.0
#
# [1757 rows x 6 columns]

# %%
test3[test3["역명"] == "마곡나루"]
# Out:
#              사용일자  노선명    역명   승차총승객수   하차총승객수    역이용자수
# 531      20190101  9호선  마곡나루   3798.0   4056.0   7854.0
# 1123     20190102  9호선  마곡나루   9459.0   9411.0  18870.0
# 1727     20190103  9호선  마곡나루   9930.0   9861.0  19791.0
# 2306     20190104  9호선  마곡나루  10350.0  10280.0  20630.0
# 2911     20190105  9호선  마곡나루   7701.0   7262.0  14963.0
# ...           ...  ...   ...      ...      ...      ...
# 1316774  20241227  9호선  마곡나루  15056.0  14862.0  29918.0
# 1317348  20241228  9호선  마곡나루   9692.0   9536.0  19228.0
# 1317972  20241229  9호선  마곡나루   6835.0   6601.0  13436.0
# 1318568  20241230  9호선  마곡나루  13857.0  13750.0  27607.0
# 1319223  20241231  9호선  마곡나루  13482.0  13258.0  26740.0
#
# [2192 rows x 6 columns]

# %%
test3 = test3.replace("동대문역사문화공원(DDP)","동대문역사문화공원")

# %%
test3[test3["역명"] == "상봉(시외터미널)"]
# Out:
# Empty DataFrame
# Columns: [사용일자, 노선명, 역명, 승차총승객수, 하차총승객수, 역이용자수]
# Index: []

# %%
test3 = test3.replace("낙성대(강감찬)","낙성대")

# %%
test3 = test3.replace("뚝섬유원지","자양(뚝섬한강공원)")

# %%
test3 = test3.replace("용마산(용마폭포공원)","용마산")

# %%
test3 = test3.replace("상봉(시외버스터미널)","상봉")

# %%
test3[test3["역명"] == "암사역사공원"]
# Out:
#              사용일자  노선명      역명   승차총승객수   하차총승객수    역이용자수
# 509      20190101  8호선  암사역사공원   7919.0   7865.0  15784.0
# 1103     20190102  8호선  암사역사공원  20643.0  18042.0  38685.0
# 1706     20190103  8호선  암사역사공원  21028.0  18606.0  39634.0
# 2285     20190104  8호선  암사역사공원  21789.0  19100.0  40889.0
# 2890     20190105  8호선  암사역사공원  14388.0  13030.0  27418.0
# ...           ...  ...     ...      ...      ...      ...
# 1317950  20241229  8호선  암사역사공원   8956.0   8553.0  17509.0
# 1318545  20241230  8호선  암사역사공원   6013.0   5221.0  11234.0
# 1318546  20241230  8호선  암사역사공원  17147.0  15922.0  33069.0
# 1319245  20241231  8호선  암사역사공원  17141.0  15625.0  32766.0
# 1319246  20241231  8호선  암사역사공원   5732.0   4908.0  10640.0
#
# [2336 rows x 6 columns]

# %%
test3 = test3.replace("암사","암사역사공원")

# %%
test3["노선명"].unique()
# Out:
# array(['2호선', '1호선', '3호선', '4호선', '경부선', '경인선', '경원선', '중앙선', '5호선',
#        '6호선', '7호선', '8호선', '9호선'], dtype=object)

# %%
sorted(test3["역명"].unique())
# Out:
# ['가능',
#  '가락시장',
#  '가산디지털단지',
#  '가양',
#  '간석',
#  '강남',
#  '강남구청',
#  '강동',
#  '강동구청',
#  '강변(동서울터미널)',
#  '강일',
#  '개롱',
#  '개봉',
#  '개화',
#  '개화산',
#  '거여',
#  '건대입구',
#  '경복궁(정부서울청사)',
#  '경찰병원',
#  '고덕',
#  '고려대(종암)',
#  '고속터미널',
#  '공덕',
#  '공릉(서울과학기술대)',
#  '공항시장',
#  '관악',
#  '광나루(장신대)',
#  '광명',
#  '광명사거리',
#  '광운대',
#  '광화문(세종문화회관)',
#  '광흥창(서강)',
#  '교대(법원.검찰청)',
#  '구로',
#  '구로디지털단지',
#  '구리',
#  '구반포',
#  '구산',
#  '구의(광진구청)',
#  '구일',
#  '구파발',
#  '국수',
#  '국회의사당',
#  '군자(능동)',
#  '군포',
#  '굴포천',
#  '굽은다리(강동구민회관앞)',
#  '금정',
#  '금천구청',
#  '금호',
#  '길동',
#  '길음',
#  '김포공항',
#  '까치산',
#  '까치울',
#  '낙성대',
#  '남구로',
#  '남부터미널(예술의전당)',
#  '남성',
#  '남영',
#  '남위례',
#  '남태령',
#  '남한산성입구(성남법원.검찰청)',
#  '내방',
#  '노들',
#  '노량진',
#  '노원',
#  '녹번',
#  '녹사평(용산구청)',
#  '녹양',
#  '녹천',
#  '논현',
#  '단대오거리',
#  '답십리',
#  '당고개',
#  '당산',
#  '당정',
#  '대림(구로구청)',
#  '대방',
#  '대청',
#  '대치',
#  '대흥(서강대앞)',
#  '덕계',
#  '덕소',
#  '덕정',
#  '도곡',
#  '도농',
#  '도림천',
#  '도봉',
#  '도봉산',
#  '도심',
# ...

# %%
test3[test3["역명"] == "까치산"]
# Out:
#              사용일자  노선명   역명   승차총승객수   하차총승객수    역이용자수
# 377      20190101  5호선  까치산  14189.0  14419.0  28608.0
# 971      20190102  5호선  까치산  32594.0  31232.0  63826.0
# 1575     20190103  5호선  까치산  33345.0  31695.0  65040.0
# 2154     20190104  5호선  까치산  34282.0  32151.0  66433.0
# 2758     20190105  5호선  까치산  24446.0  23358.0  47804.0
# ...           ...  ...  ...      ...      ...      ...
# 1316924  20241227  5호선  까치산  30220.0  28743.0  58963.0
# 1317198  20241228  5호선  까치산  21846.0  20411.0  42257.0
# 1317820  20241229  5호선  까치산  15769.0  15404.0  31173.0
# 1318416  20241230  5호선  까치산  28712.0  27616.0  56328.0
# 1319520  20241231  5호선  까치산  28999.0  26951.0  55950.0
#
# [2192 rows x 6 columns]

# %%
test3[test3["노선명"] == "중앙선"]
# Out:
#              사용일자  노선명  역명   승차총승객수   하차총승객수    역이용자수
# 271      20190101  중앙선  회기  12769.0  13842.0  26611.0
# 272      20190101  중앙선  중랑   2803.0   2877.0   5680.0
# 273      20190101  중앙선  상봉   3227.0   3105.0   6332.0
# 274      20190101  중앙선  망우   3986.0   4057.0   8043.0
# 275      20190101  중앙선  양원    657.0    688.0   1345.0
# ...           ...  ...  ..      ...      ...      ...
# 1319514  20241231  중앙선  양원   3144.0   2943.0   6087.0
# 1319515  20241231  중앙선  망우   7758.0   7500.0  15258.0
# 1319516  20241231  중앙선  상봉   6057.0   5829.0  11886.0
# 1319517  20241231  중앙선  중랑   5799.0   5330.0  11129.0
# 1319518  20241231  중앙선  회기  26235.0  23257.0  49492.0
#
# [46032 rows x 6 columns]

# %%
test3["노선명"].unique()
# Out:
# array(['2호선', '1호선', '3호선', '4호선', '경부선', '경인선', '경원선', '중앙선', '5호선',
#        '6호선', '7호선', '8호선', '9호선'], dtype=object)

# %%
test4[test4["역명"] == "회기"] = test3[test3["역명"] == "회기"].replace("중앙선", "1호선")

# %%
test4 = test3

# %%
test4
# Out:
#              사용일자  노선명     역명   승차총승객수   하차총승객수     역이용자수
# 0        20190101  2호선  을지로4가   3862.0   3728.0    7590.0
# 1        20190101  2호선  을지로3가   8104.0   7554.0   15658.0
# 2        20190101  2호선  을지로입구  22478.0  21330.0   43808.0
# 3        20190101  2호선     시청   8381.0   6049.0   14430.0
# 4        20190101  1호선    동묘앞   8045.0   8504.0   16549.0
# ...           ...  ...    ...      ...      ...       ...
# 1319516  20241231  중앙선     상봉   6057.0   5829.0   11886.0
# 1319517  20241231  중앙선     중랑   5799.0   5330.0   11129.0
# 1319518  20241231  중앙선     회기  26235.0  23257.0   49492.0
# 1319520  20241231  5호선    까치산  28999.0  26951.0   55950.0
# 1319521  20241231  1호선    서울역  68306.0  65968.0  134274.0
#
# [929308 rows x 6 columns]

# %%
test4[test4["역명"] == "회기"]
# Out:
#              사용일자  노선명  역명   승차총승객수   하차총승객수    역이용자수
# 271      20190101  1호선  회기  12769.0  13842.0  26611.0
# 867      20190102  1호선  회기  26769.0  27064.0  53833.0
# 1470     20190103  1호선  회기  27940.0  27770.0  55710.0
# 2052     20190104  1호선  회기  29757.0  29092.0  58849.0
# 2655     20190105  1호선  회기  26220.0  25362.0  51582.0
# ...           ...  ...  ..      ...      ...      ...
# 1316494  20241227  1호선  회기  27131.0  24958.0  52089.0
# 1317670  20241228  1호선  회기  24046.0  22054.0  46100.0
# 1318289  20241229  1호선  회기  16522.0  16320.0  32842.0
# 1318884  20241230  1호선  회기  25793.0  24300.0  50093.0
# 1319518  20241231  1호선  회기  26235.0  23257.0  49492.0
#
# [2192 rows x 6 columns]

# %%
test4[test4["노선명"] == "중앙선"]["역명"].unique()
# Out:
# array(['중랑', '상봉', '망우', '양원', '구리', '도농', '양정', '덕소', '도심', '팔당', '운길산',
#        '양수', '신원', '국수', '아신', '오빈', '양평', '원덕', '용문', '지평'], dtype=object)

# %%
test4[test4["노선명"] == "1호선"]["역명"].unique()
# Out:
# array(['동묘앞', '청량리(서울시립대입구)', '제기동', '신설동', '동대문', '종로5가', '종각', '회기',
#        '서울역', '시청', '종로3가'], dtype=object)

# %%
test4 = test4.drop(test4[test4["노선명"] == "중앙선"].index)

# %%
test4[test4["노선명"] == "중앙선"]
# Out:
# Empty DataFrame
# Columns: [사용일자, 노선명, 역명, 승차총승객수, 하차총승객수, 역이용자수]
# Index: []

# %%
test4.describe() # 19년 1월 부터 24년 12월까지의 통계
# Out:
#                사용일자         승차총승객수         하차총승객수          역이용자수
# count  8.854680e+05  885468.000000  885468.000000  885468.000000
# mean   2.021566e+07   13018.855993   12987.672151   26006.528143
# std    1.708810e+04   11932.138995   12123.876920   24016.969260
# min    2.019010e+07       0.000000       0.000000       1.000000
# 25%    2.020070e+07    5226.000000    5081.000000   10333.000000
# 50%    2.021123e+07    9523.000000    9390.000000   18929.000000
# 75%    2.023070e+07   16780.000000   16830.000000   33568.000000
# max    2.024123e+07  132727.000000  139617.000000  270553.000000

# %%
test4[test4["역명"] == "지축"] # test4 는 중복이름 제거 후 회기를 1호선에 추가
# Out:
#              사용일자  노선명  역명  승차총승객수  하차총승객수    역이용자수
# 57       20190101  3호선  지축   393.0   497.0    890.0
# 653      20190102  3호선  지축  1065.0  1229.0   2294.0
# 1255     20190103  3호선  지축  1142.0  1326.0   2468.0
# 1838     20190104  3호선  지축  1178.0  1305.0   2483.0
# 2442     20190105  3호선  지축   854.0   988.0   1842.0
# ...           ...  ...  ..     ...     ...      ...
# 1316992  20241227  3호선  지축  8211.0  8059.0  16270.0
# 1317129  20241228  3호선  지축  5778.0  5301.0  11079.0
# 1317752  20241229  3호선  지축  4232.0  3983.0   8215.0
# 1318348  20241230  3호선  지축  8014.0  7917.0  15931.0
# 1319440  20241231  3호선  지축  7667.0  7658.0  15325.0
#
# [2192 rows x 6 columns]

# %%
test5 = test4 # test5부터는 1호선 통합

# %%
test5 = test5.drop(test5[test5["역명"] == "지축"].index)

# %%
test4[test4["노선명"] == "5호선"]["역명"].unique()
# Out:
# array(['방화', '개화산', '김포공항', '송정', '마곡', '발산', '우장산', '화곡', '까치산',
#        '신정(은행정)', '목동', '오목교(목동운동장앞)', '양평', '영등포구청', '영등포시장', '신길',
#        '여의도', '여의나루', '마포', '공덕', '애오개', '충정로(경기대입구)', '서대문',
#        '광화문(세종문화회관)', '종로3가', '을지로4가', '동대문역사문화공원', '청구', '신금호', '행당',
#        '왕십리(성동구청)', '마장', '답십리', '장한평', '군자(능동)', '아차산(어린이대공원후문)',
#        '광나루(장신대)', '천호(풍납토성)', '강동', '길동', '굽은다리(강동구민회관앞)', '명일', '고덕',
#        '상일동', '둔촌동', '올림픽공원(한국체대)', '방이', '오금', '개롱', '거여', '마천', '미사',
#        '하남풍산', '하남검단산', '하남시청(덕풍·신장)', '강일'], dtype=object)

# %%
test5 = test5.drop(test5[(test5["역명"] == "미사") | (test5["역명"] == "하남풍산") | (test5["역명"] == "하남검단산") | (test5["역명"] == "하남시청(덕풍·신장)")].index)

# %%
test5[test5["노선명"] == "5호선"]["역명"].unique()
# Out:
# array(['방화', '개화산', '김포공항', '송정', '마곡', '발산', '우장산', '화곡', '까치산',
#        '신정(은행정)', '목동', '오목교(목동운동장앞)', '양평', '영등포구청', '영등포시장', '신길',
#        '여의도', '여의나루', '마포', '공덕', '애오개', '충정로(경기대입구)', '서대문',
#        '광화문(세종문화회관)', '종로3가', '을지로4가', '동대문역사문화공원', '청구', '신금호', '행당',
#        '왕십리(성동구청)', '마장', '답십리', '장한평', '군자(능동)', '아차산(어린이대공원후문)',
#        '광나루(장신대)', '천호(풍납토성)', '강동', '길동', '굽은다리(강동구민회관앞)', '명일', '고덕',
#        '상일동', '둔촌동', '올림픽공원(한국체대)', '방이', '오금', '개롱', '거여', '마천', '강일'],
#       dtype=object)

# %%
test4["노선명"].unique()
# Out:
# array(['2호선', '1호선', '3호선', '4호선', '경부선', '경인선', '경원선', '5호선', '6호선',
#        '7호선', '8호선', '9호선'], dtype=object)

# %%
test4[test4["노선명"] == "1호선"]["역명"].unique()
# Out:
# array(['동묘앞', '청량리(서울시립대입구)', '제기동', '신설동', '동대문', '종로5가', '종각', '회기',
#        '서울역', '시청', '종로3가'], dtype=object)

# %%
test4[test4["노선명"] == "경부선"]["역명"].unique()
# Out:
# array(['서울역', '남영', '용산', '노량진', '대방', '영등포', '신도림', '신길', '구로',
#        '가산디지털단지', '금천구청', '석수', '관악', '안양', '명학', '금정', '군포', '의왕',
#        '성균관대', '화서', '수원', '독산', '세류', '병점', '세마', '오산대', '오산', '진위',
#        '송탄', '서정리', '지제', '평택', '성환', '직산', '두정', '천안', '당정', '서동탄', '광명',
#        '평택지제'], dtype=object)

# %%
test4[test4["노선명"] == "경인선"]["역명"].unique()
# Out:
# array(['개봉', '오류동', '역곡', '부천', '송내', '부평', '백운', '동암', '주안', '제물포',
#        '동인천', '인천', '구일', '소사', '부개', '간석', '도원', '온수(성공회대입구)', '중동',
#        '도화'], dtype=object)

# %%
test4[test4["노선명"] == "경원선"]["역명"].unique()
# Out:
# array(['이촌(국립중앙박물관)', '서빙고', '한남', '옥수', '응봉', '왕십리(성동구청)',
#        '청량리(서울시립대입구)', '외대앞', '신이문', '석계', '광운대', '월계', '녹천', '창동', '방학',
#        '도봉', '도봉산', '망월사', '회룡', '의정부', '가능', '녹양', '양주', '덕계', '덕정',
#        '지행', '동두천중앙', '보산', '동두천', '소요산', '연천', '전곡', '초성리', '청산'],
#       dtype=object)

# %%
test6 = test4

# %%
test6["노선명"].unique()
# Out:
# array(['2호선', '1호선', '3호선', '4호선', '경부선', '경인선', '경원선', '5호선', '6호선',
#        '7호선', '8호선', '9호선'], dtype=object)

# %%
test6 = test6.drop(test6[(test6["노선명"] == "경부선") | (test6["노선명"] == "경인선") | (test6["노선명"] == "경원선")].index)

# %%
test6["노선명"].unique()
# Out:
# array(['2호선', '1호선', '3호선', '4호선', '5호선', '6호선', '7호선', '8호선', '9호선'],
#       dtype=object)

# %%
test6 = test6.drop(test6[test6["역명"] == "회기"].index)

# %%
test6[test6["역명"] == "회기"]
# Out:
# Empty DataFrame
# Columns: [사용일자, 노선명, 역명, 승차총승객수, 하차총승객수, 역이용자수]
# Index: []

# %%
test6
# Out:
#              사용일자  노선명     역명   승차총승객수   하차총승객수     역이용자수
# 0        20190101  2호선  을지로4가   3862.0   3728.0    7590.0
# 1        20190101  2호선  을지로3가   8104.0   7554.0   15658.0
# 2        20190101  2호선  을지로입구  22478.0  21330.0   43808.0
# 3        20190101  2호선     시청   8381.0   6049.0   14430.0
# 4        20190101  1호선    동묘앞   8045.0   8504.0   16549.0
# ...           ...  ...    ...      ...      ...       ...
# 1319496  20241231  1호선   종로5가  26742.0  25213.0   51955.0
# 1319497  20241231  1호선   종로3가  31445.0  27304.0   58749.0
# 1319498  20241231  1호선     종각  41994.0  42616.0   84610.0
# 1319520  20241231  5호선    까치산  28999.0  26951.0   55950.0
# 1319521  20241231  1호선    서울역  68306.0  65968.0  134274.0
#
# [688366 rows x 6 columns]

# %%
test6.to_csv("./data/metro/data/19~24년도1~9호선데이터.csv", index = False, encoding = "utf-8-sig")

# %%
test6[test6["노선명"] == "3호선"]["역명"].unique()
# Out:
# array(['지축', '구파발', '연신내', '불광', '녹번', '홍제', '무악재', '독립문', '경복궁(정부서울청사)',
#        '안국', '종로3가', '을지로3가', '충무로', '동대입구', '약수', '금호', '옥수', '압구정',
#        '신사', '잠원', '고속터미널', '교대(법원.검찰청)', '남부터미널(예술의전당)', '양재(서초구청)',
#        '매봉', '도곡', '대치', '학여울', '대청', '일원', '수서', '가락시장', '경찰병원', '오금'],
#       dtype=object)

# %%
test6[test6["노선명"] == "7호선"]["역명"].unique()
# Out:
# array(['장암', '도봉산', '수락산', '마들', '노원', '중계', '하계', '공릉(서울과학기술대)', '태릉입구',
#        '먹골', '중화', '상봉', '면목', '사가정', '용마산', '중곡', '군자(능동)',
#        '어린이대공원(세종대)', '건대입구', '자양(뚝섬한강공원)', '청담', '강남구청', '학동', '논현',
#        '반포', '고속터미널', '내방', '이수', '남성', '숭실대입구(살피재)', '상도', '장승배기',
#        '신대방삼거리', '보라매', '신풍', '대림(구로구청)', '남구로', '가산디지털단지', '철산', '광명사거리',
#        '천왕', '온수(성공회대입구)', '까치울', '부천종합운동장', '춘의', '신중동', '부천시청', '상동',
#        '삼산체육관', '굴포천', '부평구청'], dtype=object)

# %%
test6[test6["노선명"] == "4호선"]["역명"].unique()
# Out:
# array(['당고개', '상계', '노원', '창동', '쌍문', '수유(강북구청)', '미아(서울사이버대학)', '미아사거리',
#        '길음', '성신여대입구(돈암)', '한성대입구(삼선교)', '혜화', '동대문', '동대문역사문화공원', '충무로',
#        '명동', '회현(남대문시장)', '서울역', '숙대입구(갈월)', '삼각지', '신용산', '이촌(국립중앙박물관)',
#        '동작(현충원)', '총신대입구(이수)', '사당', '남태령'], dtype=object)

# %%
test7 = test6 # test7은 년도별 카피 시험 데이터

# %%
test7.iloc[:114736]
# Out:
#             사용일자  노선명     역명   승차총승객수   하차총승객수    역이용자수
# 0       20190101  2호선  을지로4가   3862.0   3728.0   7590.0
# 1       20190101  2호선  을지로3가   8104.0   7554.0  15658.0
# 2       20190101  2호선  을지로입구  22478.0  21330.0  43808.0
# 3       20190101  2호선     시청   8381.0   6049.0  14430.0
# 4       20190101  1호선    동묘앞   8045.0   8504.0  16549.0
# ...          ...  ...    ...      ...      ...      ...
# 215762  20191231  9호선    신반포   3255.0   3107.0   6362.0
# 215763  20191231  9호선  고속터미널  15593.0  23750.0  39343.0
# 215764  20191231  9호선     사평   3525.0   3391.0   6916.0
# 215765  20191231  9호선    신논현  38032.0  38915.0  76947.0
# 215769  20200101  1호선     종각  20427.0  16301.0  36728.0
#
# [114736 rows x 6 columns]

# %%
test2019 = test7.iloc[:114735].copy(deep=True)

# %%
test2019.to_csv("./data/metro/data/2019년도1~9호선데이터.csv", index = False, encoding = "utf-8-sig")

# %%
test2019
# Out:
#             사용일자  노선명     역명   승차총승객수   하차총승객수    역이용자수
# 0       20190101  2호선  을지로4가   3862.0   3728.0   7590.0
# 1       20190101  2호선  을지로3가   8104.0   7554.0  15658.0
# 2       20190101  2호선  을지로입구  22478.0  21330.0  43808.0
# 3       20190101  2호선     시청   8381.0   6049.0  14430.0
# 4       20190101  1호선    동묘앞   8045.0   8504.0  16549.0
# ...          ...  ...    ...      ...      ...      ...
# 215761  20191231  9호선    구반포   3141.0   3237.0   6378.0
# 215762  20191231  9호선    신반포   3255.0   3107.0   6362.0
# 215763  20191231  9호선  고속터미널  15593.0  23750.0  39343.0
# 215764  20191231  9호선     사평   3525.0   3391.0   6916.0
# 215765  20191231  9호선    신논현  38032.0  38915.0  76947.0
#
# [114735 rows x 6 columns]

# %%
test2020 = test7.iloc[114735:229970].copy(deep=True)

# %%
test2020.to_csv("./data/metro/data/2020년도1~9호선데이터.csv", index = False, encoding = "utf-8-sig")

# %%
test2021 = test7.iloc[229970:346251].copy(deep=True)

# %%
test2021.to_csv("./data/metro/data/2021년도1~9호선데이터.csv", index = False, encoding = "utf-8-sig")

# %%
test2022 = test7.iloc[346251:460211].copy(deep=True)

# %%
test2022.to_csv("./data/metro/data/2022년도1~9호선데이터.csv", index = False, encoding = "utf-8-sig")

# %%
test2023 = test7.iloc[460211:573944].copy(deep=True)

# %%
test2023.to_csv("./data/metro/data/2023년도1~9호선데이터.csv", index = False, encoding = "utf-8-sig")

# %%
test2024 = test7.iloc[573944:688366].copy(deep=True)

# %%
test2024.to_csv("./data/metro/data/2024년도1~9호선데이터.csv", index = False, encoding = "utf-8-sig")

# %%
test8 = test6.reset_index().drop("index", axis=1) # test8은 테스트6에서 인덱스를 정리한 데이터

# %%
test8["역명"]
# Out:
#             사용일자  노선명     역명   승차총승객수   하차총승객수     역이용자수
# 0       20190101  2호선  을지로4가   3862.0   3728.0    7590.0
# 1       20190101  2호선  을지로3가   8104.0   7554.0   15658.0
# 2       20190101  2호선  을지로입구  22478.0  21330.0   43808.0
# 3       20190101  2호선     시청   8381.0   6049.0   14430.0
# 4       20190101  1호선    동묘앞   8045.0   8504.0   16549.0
# ...          ...  ...    ...      ...      ...       ...
# 688361  20241231  1호선   종로5가  26742.0  25213.0   51955.0
# 688362  20241231  1호선   종로3가  31445.0  27304.0   58749.0
# 688363  20241231  1호선     종각  41994.0  42616.0   84610.0
# 688364  20241231  5호선    까치산  28999.0  26951.0   55950.0
# 688365  20241231  1호선    서울역  68306.0  65968.0  134274.0
#
# [688366 rows x 6 columns]

# %%
group2호선 = test8.groupby("노선명")

# %%
group2호선["역이용자수"].mean()
# Out:
# 노선명
# 1호선    43266.391286
# 2호선    50799.323896
# 3호선    28220.318233
# 4호선    35852.750035
# 5호선    20741.820471
# 6호선    16002.115599
# 7호선    24551.310216
# 8호선    19514.079677
# 9호선    17668.722412
# Name: 역이용자수, dtype: float64

# %%
test8.describe()
# Out:
#                사용일자         승차총승객수         하차총승객수          역이용자수
# count  6.883660e+05  688366.000000  688366.000000  688366.000000
# mean   2.021561e+07   13923.948578   13930.665973   27854.614551
# std    1.706969e+04   12502.243716   12659.180468   25118.964103
# min    2.019010e+07       1.000000       0.000000       1.000000
# 25%    2.020070e+07    5823.250000    5739.000000   11600.000000
# 50%    2.021122e+07   10396.000000   10333.000000   20738.000000
# 75%    2.023063e+07   17681.000000   17820.750000   35413.000000
# max    2.024123e+07  132727.000000  139617.000000  270553.000000

# %%
test8["하차총승객수"].sum()
# Out:
# 9589396813.0

# %%
sub19 = pd.read_csv("./data/metro/data/2019년도1~9호선데이터.csv")

# %%
sub20 = pd.read_csv("./data/metro/data/2020년도1~9호선데이터.csv")

# %%
sub21 = pd.read_csv("./data/metro/data/2021년도1~9호선데이터.csv")

# %%
sub22 = pd.read_csv("./data/metro/data/2022년도1~9호선데이터.csv")

# %%
sub23 = pd.read_csv("./data/metro/data/2023년도1~9호선데이터.csv")

# %%
sub24 = pd.read_csv("./data/metro/data/2024년도1~9호선데이터.csv")

# %%
sub19["역이용자수"].mean()
# Out:
# 32963.697476794354

# %%
sub20["역이용자수"].mean()
# Out:
# 23865.43686380006

# %%
sub21["역이용자수"].mean()
# Out:
# 23885.55108745195

# %%
sub22["역이용자수"].mean()
# Out:
# 26864.0232011232

# %%
sub23["역이용자수"].mean()
# Out:
# 29429.62548248969

# %%
sub24["역이용자수"].mean()
# Out:
# 30203.690793728478

# %%
year1924 = pd.Series(
    index = ["2019","2020","2021","2022","2023","2024"],
    data = [sub19["역이용자수"].mean(),sub20["역이용자수"].mean(),sub21["역이용자수"].mean(),sub22["역이용자수"].mean()
           ,sub23["역이용자수"].mean(),sub24["역이용자수"].mean()],
    name = "19년부터 24년까지의 역이용자수 평균"
)

# %%
year1924
# Out:
# 2019    32963.697477
# 2020    23865.436864
# 2021    23885.551087
# 2022    26864.023201
# 2023    29429.625482
# 2024    30203.690794
# Name: 19년부터 24년까지의 역이용자수 평균, dtype: float64

# %%
import matplotlib.pyplot as plt

# Windows용 한글 폰트 오류 해결
from matplotlib import font_manager, rc
font_path = "C:/Windows/Fonts/malgun.ttf"
font_name = font_manager.FontProperties(fname = font_path).get_name()
rc("font", family = font_name)

# %%
fig = plt.figure(figsize = (10,5))
plt.plot(year1924, "b-o") # 시리즈의 벨류들이 그대로 y축의 값이 된다, 인덱스는 x축
plt.grid()
plt.xlabel("연도")
plt.ylabel("이용수")
plt.title("19~24년도 역이용자수 평균 추이 (역이용자는 각 역의 승하차인원의 합계)")

plt.show()

# %%
test7["역명"].unique()
# Out:
# array(['을지로4가', '을지로3가', '을지로입구', '시청', '동묘앞', '청량리(서울시립대입구)', '제기동',
#        '신설동', '동대문', '종로5가', '종각', '동대문역사문화공원', '신당', '상왕십리', '왕십리(성동구청)',
#        '한양대', '뚝섬', '성수', '건대입구', '구의(광진구청)', '강변(동서울터미널)', '잠실나루',
#        '잠실(송파구청)', '잠실새내', '종합운동장', '삼성(무역센터)', '선릉', '역삼', '강남',
#        '교대(법원.검찰청)', '서초', '방배', '사당', '낙성대', '서울대입구(관악구청)', '봉천', '신림',
#        '신대방', '구로디지털단지', '대림(구로구청)', '신도림', '문래', '영등포구청', '당산', '합정',
#        '홍대입구', '신촌', '이대', '아현', '충정로(경기대입구)', '용답', '신답', '도림천', '양천구청',
#        '신정네거리', '용두(동대문구청)', '지축', '구파발', '연신내', '불광', '녹번', '홍제', '무악재',
#        '독립문', '경복궁(정부서울청사)', '안국', '종로3가', '충무로', '동대입구', '약수', '금호',
#        '옥수', '압구정', '신사', '잠원', '고속터미널', '남부터미널(예술의전당)', '양재(서초구청)', '매봉',
#        '도곡', '대치', '학여울', '대청', '일원', '수서', '가락시장', '경찰병원', '오금', '당고개',
#        '상계', '노원', '창동', '쌍문', '수유(강북구청)', '미아(서울사이버대학)', '미아사거리', '길음',
#        '성신여대입구(돈암)', '한성대입구(삼선교)', '혜화', '명동', '회현(남대문시장)', '서울역',
# ...

# %%
test7 = test7.replace("청량리(서울시립대입구)","청량리")
test7 = test7.replace("왕십리(성동구청)","왕십리")
test7 = test7.replace("구의(광진구청)","구의")
test7 = test7.replace("강변(동서울터미널)","강변")
test7 = test7.replace("잠실(송파구청)","잠실")
test7 = test7.replace("삼성(무역센터)","삼성")
test7 = test7.replace("교대(법원.검찰청)","교대")
test7 = test7.replace("서울대입구(관악구청)","서울대입구")
test7 = test7.replace("대림(구로구청)","대림")
test7 = test7.replace("충정로(경기대입구)","충정로")
test7 = test7.replace("용두(동대문구청)","용두")
test7 = test7.replace("경복궁(정부서울청사)","경복궁")
test7 = test7.replace("남부터미널(예술의전당)","남부터미널")
test7 = test7.replace("양재(서초구청)","양재")
test7 = test7.replace("수유(강북구청)","수유")
test7 = test7.replace("미아(서울사이버대학)","미아")
test7 = test7.replace("성신여대입구(돈암)","성신여대입구")
test7 = test7.replace("한성대입구(삼선교)","한성대입구")
test7 = test7.replace("회현(남대문시장)","회현")
test7 = test7.replace("숙대입구(갈월)","숙대입구")
test7 = test7.replace("이촌(국립중앙박물관)","이촌")
test7 = test7.replace("동작(현충원)","동작")
test7 = test7.replace("총신대입구(이수)","총신대입구")
test7 = test7.replace("신정(은행정)","신정")
test7 = test7.replace("오목교(목동운동장앞)","오목교")
test7 = test7.replace("광화문(세종문화회관)","광화문")
test7 = test7.replace("군자(능동)","군자")
test7 = test7.replace("아차산(어린이대공원후문)","아차산")
test7 = test7.replace("광나루(장신대)","광나루")
test7 = test7.replace("천호(풍납토성)","천호")
test7 = test7.replace("굽은다리(강동구민회관앞)","굽은다리")
test7 = test7.replace("올림픽공원(한국체대)","올림픽공원")
test7 = test7.replace("새절(신사)","새절")
test7 = test7.replace("증산(명지대앞)","증산")
test7 = test7.replace("월드컵경기장(성산)","월드컵경기장")
test7 = test7.replace("광흥창(서강)","광흥창")
test7 = test7.replace("대흥(서강대앞)","대흥")
test7 = test7.replace("녹사평(용산구청)","녹사평")
test7 = test7.replace("안암(고대병원앞)","안암")
test7 = test7.replace("고려대(종암)","고려대")
test7 = test7.replace("월곡(동덕여대)","월곡")
test7 = test7.replace("상월곡(한국과학기술연구원)","상월곡")
test7 = test7.replace("화랑대(서울여대입구)","화랑대")
test7 = test7.replace("봉화산(서울의료원)","봉화산")
test7 = test7.replace("공릉(서울과학기술대)","공릉")
test7 = test7.replace("어린이대공원(세종대)","어린이대공원")
test7 = test7.replace("자양(뚝섬한강공원)","자양")
test7 = test7.replace("숭실대입구(살피재)","숭실대입구")
test7 = test7.replace("온수(성공회대입구)","온수")
test7 = test7.replace("몽촌토성(평화의문)","몽촌토성")
test7 = test7.replace("남한산성입구(성남법원.검찰청)","남한산성입구")
test7 = test7.replace("흑석(중앙대입구)","흑석")
test7 = test7.replace("하남시청(덕풍·신장)","하남시청")

# %%
test7["역명"].unique()
# Out:
# array(['을지로4가', '을지로3가', '을지로입구', '시청', '동묘앞', '청량리', '제기동', '신설동', '동대문',
#        '종로5가', '종각', '동대문역사문화공원', '신당', '상왕십리', '왕십리', '한양대', '뚝섬', '성수',
#        '건대입구', '구의', '강변', '잠실나루', '잠실', '잠실새내', '종합운동장', '삼성', '선릉',
#        '역삼', '강남', '교대', '서초', '방배', '사당', '낙성대', '서울대입구', '봉천', '신림',
#        '신대방', '구로디지털단지', '대림', '신도림', '문래', '영등포구청', '당산', '합정', '홍대입구',
#        '신촌', '이대', '아현', '충정로', '용답', '신답', '도림천', '양천구청', '신정네거리', '용두',
#        '지축', '구파발', '연신내', '불광', '녹번', '홍제', '무악재', '독립문', '경복궁', '안국',
#        '종로3가', '충무로', '동대입구', '약수', '금호', '옥수', '압구정', '신사', '잠원',
#        '고속터미널', '남부터미널', '양재', '매봉', '도곡', '대치', '학여울', '대청', '일원', '수서',
#        '가락시장', '경찰병원', '오금', '당고개', '상계', '노원', '창동', '쌍문', '수유', '미아',
#        '미아사거리', '길음', '성신여대입구', '한성대입구', '혜화', '명동', '회현', '서울역', '숙대입구',
#        '삼각지', '신용산', '이촌', '동작', '총신대입구', '남태령', '방화', '개화산', '김포공항',
#        '송정', '마곡', '발산', '우장산', '화곡', '까치산', '신정', '목동', '오목교', '양평',
# ...

# %%
test7_2 = test7.reset_index()

# %%
test7_2 = test7_2.drop("index",axis=1)

# %%
test7_2 # 가로를 제거한 데이터에 인덱스도 정리한 버전
# Out:
#             사용일자  노선명     역명   승차총승객수   하차총승객수     역이용자수
# 0       20190101  2호선  을지로4가   3862.0   3728.0    7590.0
# 1       20190101  2호선  을지로3가   8104.0   7554.0   15658.0
# 2       20190101  2호선  을지로입구  22478.0  21330.0   43808.0
# 3       20190101  2호선     시청   8381.0   6049.0   14430.0
# 4       20190101  1호선    동묘앞   8045.0   8504.0   16549.0
# ...          ...  ...    ...      ...      ...       ...
# 688361  20241231  1호선   종로5가  26742.0  25213.0   51955.0
# 688362  20241231  1호선   종로3가  31445.0  27304.0   58749.0
# 688363  20241231  1호선     종각  41994.0  42616.0   84610.0
# 688364  20241231  5호선    까치산  28999.0  26951.0   55950.0
# 688365  20241231  1호선    서울역  68306.0  65968.0  134274.0
#
# [688366 rows x 6 columns]

# %%
test7_2.to_csv("./data/metro/data/19~24년도1~9호선데이터(소괄호제거,인덱스정리 버전).csv", index=False, encoding="utf-8-sig")

# %%
test10 = test7_2 # test10은 시각화를 위해 가지고 놀기 위한 데이터

# %%
test10.shape
# Out:
# (688366, 6)

# %%
test10.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 688366 entries, 0 to 688365
# Data columns (total 6 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   사용일자    688366 non-null  int64
#  1   노선명     688366 non-null  object
#  2   역명      688366 non-null  object
#  3   승차총승객수  688366 non-null  float64
#  4   하차총승객수  688366 non-null  float64
#  5   역이용자수   688366 non-null  float64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 31.5+ MB

# %%
test10[test10["노선명"] == "2호선"]
# Out:
#             사용일자  노선명         역명   승차총승객수   하차총승객수     역이용자수
# 0       20190101  2호선      을지로4가   3862.0   3728.0    7590.0
# 1       20190101  2호선      을지로3가   8104.0   7554.0   15658.0
# 2       20190101  2호선      을지로입구  22478.0  21330.0   43808.0
# 3       20190101  2호선         시청   8381.0   6049.0   14430.0
# 11      20190101  2호선  동대문역사문화공원  10995.0  11808.0   22803.0
# ...          ...  ...        ...      ...      ...       ...
# 688351  20241231  2호선  동대문역사문화공원  19280.0  22791.0   42071.0
# 688352  20241231  2호선      을지로4가  15621.0  15425.0   31046.0
# 688353  20241231  2호선      을지로3가  26702.0  26285.0   52987.0
# 688354  20241231  2호선      을지로입구  60555.0  58231.0  118786.0
# 688355  20241231  2호선         시청  29563.0  27728.0   57291.0
#
# [109600 rows x 6 columns]

# %%
from datetime import datetime

# %%
test20 = pd.read_csv("./data/metro/data/2024년도1~9호선데이터.csv")

# %%
# test12 는 금요일 시작할때 사용할 버전

# %%
test20["datetime"] = pd.to_datetime(test12["사용일자"],format='%Y%m%d')

# %%
test20
# Out:
#             사용일자  노선명     역명   승차총승객수   하차총승객수     역이용자수   datetime
# 0       20240101  5호선    애오개   2130.0   2279.0    4409.0 2019-01-01
# 1       20240101  9호선  고속터미널  10854.0  12465.0   23319.0 2019-01-01
# 2       20240101  9호선    신반포   1325.0   1348.0    2673.0 2019-01-01
# 3       20240101  9호선    구반포    263.0    284.0     547.0 2019-01-01
# 4       20240101  9호선     동작   1537.0   1358.0    2895.0 2019-01-01
# ...          ...  ...    ...      ...      ...       ...        ...
# 114417  20241231  1호선   종로5가  26742.0  25213.0   51955.0 2019-12-30
# 114418  20241231  1호선   종로3가  31445.0  27304.0   58749.0 2019-12-30
# 114419  20241231  1호선     종각  41994.0  42616.0   84610.0 2019-12-30
# 114420  20241231  5호선    까치산  28999.0  26951.0   55950.0 2019-12-31
# 114421  20241231  1호선    서울역  68306.0  65968.0  134274.0 2019-12-31
#
# [114422 rows x 7 columns]

# %%
sub_in = test20.groupby(["노선명","역명"])["승차총승객수"].agg(["mean"])

# %%
sub_out = test20.groupby(["노선명","역명"])["하차총승객수"].agg(["mean"])

# %%
sub_in = sub_in.reset_index()

# %%
sub_out = sub_out.reset_index()

# %%
sub_in["mean"] = sub_in["mean"].astype("int")

# %%
sub_out["mean"] = sub_out["mean"].astype("int")

# %%
sub_in["평균승차총승객수"] = sub_in["mean"]

# %%
sub_out["평균하차총승객수"] = sub_out["mean"]

# %%
sub_in
# Out:
#      노선명      역명   mean  평균승차총승객수
# 0    1호선     동대문  11976     11976
# 1    1호선     동묘앞  10381     10381
# 2    1호선     서울역  53940     53940
# 3    1호선      시청  24953     24953
# 4    1호선     신설동  13650     13650
# ..   ...     ...    ...       ...
# 313  9호선   종합운동장   4978      4978
# 314  9호선  중앙보훈병원  11073     11073
# 315  9호선      증미   7315      7315
# 316  9호선    한성백제   3046      3046
# 317  9호선      흑석   9061      9061
#
# [318 rows x 4 columns]

# %%
sub_out
# Out:
#      노선명      역명   mean  평균하차총승객수
# 0    1호선     동대문  11835     11835
# 1    1호선     동묘앞  10633     10633
# 2    1호선     서울역  51270     51270
# 3    1호선      시청  24960     24960
# 4    1호선     신설동  13191     13191
# ..   ...     ...    ...       ...
# 313  9호선   종합운동장   4866      4866
# 314  9호선  중앙보훈병원   9778      9778
# 315  9호선      증미   7056      7056
# 316  9호선    한성백제   2688      2688
# 317  9호선      흑석   9174      9174
#
# [318 rows x 4 columns]

# %%
total1["평균승차총승객수"] = sub_in["평균승차총승객수"]

# %%
total1["평균하차총승객수"] = sub_out["평균하차총승객수"]

# %%
total1["평균역이용자수"] = total1["mean"]

# %%
total1["평균역이용자수max"] = total1["max"]

# %%
total1["평균역이용자수min"] = total1["min"]

# %%
total1 = total1.drop(["mean","max","min"],axis=1)

# %%
total1.to_csv("./data/metro/data/1-9호선 통합본(2).csv", index = False, encoding = "utf-8-sig")

# %%
bic = total1[["평균승차총승객수","평균하차총승객수","자전거보관소 대수"]]

# %%
bic
# Out:
#      평균승차총승객수  평균하차총승객수  자전거보관소 대수
# 0       11976     11835       30.0
# 1       10381     10633        6.0
# 2       53940     51270       10.0
# 3       24953     24960       25.0
# 4       13650     13191       66.0
# ..        ...       ...        ...
# 313      4978      4866       20.0
# 314     11073      9778      210.0
# 315      7315      7056       30.0
# 316      3046      2688      200.0
# 317      9061      9174       40.0
#
# [318 rows x 3 columns]

# %%
test21 = test20.drop(["사용일자","승차총승객수","하차총승객수"],axis = 1) 
# test13 : 컬럼을 3개로 줄인 버전

# %%
test21.dtypes
# Out:
# 노선명                 object
# 역명                  object
# 역이용자수              float64
# datetime    datetime64[ns]
# dtype: object

# %%
test22 = test21.groupby(["노선명","역명"])["역이용자수"].agg(["mean","max","min"])
# test14 : 노선명과 역명으로 그룹해서 평균 최대 최소 구한 프레임

# %%
test22
# Out:
#                      mean       max      min
# 노선명 역명
# 1호선 동대문      23812.207650   35181.0  16032.0
#     동묘앞      21015.155738   37417.0  12384.0
#     서울역     105211.521858  139845.0  65919.0
#     시청       49914.622951   74556.0  17937.0
#     신설동      26842.128415   37009.0   9983.0
# ...                   ...       ...      ...
# 9호선 종합운동장     9845.196721   15620.0   2730.0
#     중앙보훈병원   20851.890710   29135.0   5508.0
#     증미       14372.595628   20485.0   3537.0
#     한성백제      5735.729508   14163.0   1628.0
#     흑석       18235.699454   29833.0   5437.0
#
# [318 rows x 3 columns]

# %%
test22 = test22.reset_index()

# %%
test22["mean"] = test22["mean"].astype("int")

# %%
test14.to_csv("./data/metro/data/노선명,역명,평균,최대,최소.csv",index = False, encoding = "utf-8-sig")

# %%
test22.shape
# Out:
# (318, 5)

# %%
test22.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 318 entries, 0 to 317
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   노선명     318 non-null    object
#  1   역명      318 non-null    object
#  2   mean    318 non-null    int32
#  3   max     318 non-null    float64
#  4   min     318 non-null    float64
# dtypes: float64(2), int32(1), object(2)
# memory usage: 11.3+ KB

# %%
len(test22["역명"].unique())
# Out:
# 275

# %%
test23 = test22

# %%
test23["역명"] = test22["역명"].sort_values()

# %%
test24 = test23.groupby("역명")["노선명"].count()

# %%
test23.groupby("노선명")["mean"].sum()
# Out:
# 노선명
# 1호선     471094
# 2호선    2719416
# 3호선    1027259
# 4호선    1027596
# 5호선    1263855
# 6호선     659735
# 7호선    1124700
# 8호선     374087
# 9호선     764320
# Name: mean, dtype: int32

# %%
test23.groupby("노선명")["mean"].mean()
# Out:
# 노선명
# 1호선    47109.400000
# 2호선    54388.320000
# 3호선    30213.500000
# 4호선    39522.923077
# 5호선    22568.839286
# 6호선    16916.282051
# 7호선    23929.787234
# 8호선    20782.611111
# 9호선    20113.684211
# Name: mean, dtype: float64

# %%
test23.groupby("노선명")["mean"].agg(["mean","max","min"])
# Out:
#              mean     max    min
# 노선명
# 1호선  47109.400000  105211  21015
# 2호선  54388.320000  155872   2550
# 3호선  30213.500000   98210      9
# 4호선  39522.923077   71551   2591
# 5호선  22568.839286   64533   6142
# 6호선  16916.282051   35326      1
# 7호선  23929.787234   75960      1
# 8호선  20782.611111   40188   9075
# 9호선  20113.684211   60502   2401

# %%
test14["노선개수"] = test16

# %%
test14 =test14.drop("index", axis = 1)

# %%
test14[test14["역명"] ==  "연신내"]
# Out:
#      노선명   역명   mean    max    min
# 83   3호선  연신내  66472  99133  21842
# 202  6호선  연신내      2     33      1

# %%
test12[test12["역명"] ==  "충무로"]
# Out:
#             사용일자  노선명   역명   승차총승객수   하차총승객수  역이용자수   datetime
# 69      20190101  3호선  충무로      2.0      0.0      2 2019-01-01
# 105     20190101  4호선  충무로  12152.0  11795.0  23947 2019-01-01
# 388     20190102  3호선  충무로      2.0      0.0      2 2019-01-02
# 424     20190102  4호선  충무로  34029.0  35055.0  69084 2019-01-02
# 702     20190103  3호선  충무로      2.0      0.0      2 2019-01-03
# ...          ...  ...  ...      ...      ...    ...        ...
# 687535  20241229  4호선  충무로  12716.0  13451.0  26167 2024-12-29
# 687809  20241230  3호선  충무로      1.0      0.0      1 2024-12-30
# 687845  20241230  4호선  충무로  32148.0  33601.0  65749 2024-12-30
# 688257  20241231  4호선  충무로  30751.0  31951.0  62702 2024-12-31
# 688293  20241231  3호선  충무로      7.0      0.0      7 2024-12-31
#
# [3783 rows x 7 columns]

# %%
test15["역명"].value_counts()
# Out:
# 역명
# 종로3가         3
# 동대문역사문화공원    3
# 고속터미널        3
# 동대문          2
# 김포공항         2
#             ..
# 거여           1
# 고덕           1
# 광나루          1
# 광화문          1
# 흑석           1
# Name: count, Length: 279, dtype: int64

# %%
test25 = test23.groupby("역명")["역명"].agg(["count"])

# %%
test25
# Out:
#          count
# 역명
# 가락시장         2
# 가산디지털단지      1
# 가양           1
# 강남           1
# 강남구청         1
# ...        ...
# 화곡           1
# 화랑대          1
# 회현           1
# 효창공원앞        1
# 흑석           1
#
# [275 rows x 1 columns]

# %%
test23 = test23.set_index("역명")

# %%
test23["노선개수"] = test25

# %%
test23 = test23.reset_index()

# %%
test23[test23["역명"] == "동대문"]
# Out:
#      역명  노선명   mean      max      min  노선개수
# 0   동대문  1호선  23812  35181.0  16032.0     2
# 98  동대문  4호선  38620  50104.0   9993.0     2

# %%
test15 = test15.drop(["개수","노선개수"],axis=1)

# %%
test23[["max","min"]] = test23[["max","min"]].astype(int)

# %%
test23.to_csv("./data/metro/data/24년도 노선명,역명별 이용객수 평균,최대,최소,노선개수.csv",index=False,encoding = "utf-8-sig")

# %%
test15.to_csv("./data/metro/data/19~24년도 노선명,역명별 이용객수 평균,최대,최소.csv", index=False, encoding = "utf-8-sig")

# %%
test23[test23["역명"] == "까치울"]
# Out:
#       역명  노선명  mean  max  min  노선개수
# 222  까치울  7호선     1    1    1     1

# %%
test20[test20["역명"] == "까치울"]
# Out:
#             사용일자  노선명   역명  승차총승객수  하차총승객수  역이용자수   datetime
# 1640    20240106  7호선  까치울     1.0     0.0    1.0 2019-01-06
# 13651   20240213  7호선  까치울     1.0     0.0    1.0 2019-02-13
# 20201   20240305  7호선  까치울     1.0     0.0    1.0 2019-03-06
# 20833   20240307  7호선  까치울     1.0     0.0    1.0 2019-03-08
# 36763   20240427  7호선  까치울     1.0     0.0    1.0 2019-04-27
# 51757   20240614  7호선  까치울     1.0     0.0    1.0 2019-06-14
# 59256   20240708  7호선  까치울     1.0     0.0    1.0 2019-07-08
# 102897  20241125  7호선  까치울     1.0     0.0    1.0 2019-11-24
# 103713  20241127  7호선  까치울     1.0     0.0    1.0 2019-11-26
# 113739  20241229  7호선  까치울     1.0     0.0    1.0 2019-12-28

# %%
CARD_SUBWAY_MONTH_2024 = pd.read_csv("./data/metro/data/CARD_SUBWAY_MONTH_2024.csv")

# %%
CARD_SUBWAY_MONTH_2024[CARD_SUBWAY_MONTH_2024["역명"] == "까치울"]
# Out:
#             사용일자  노선명   역명  승차총승객수  하차총승객수      등록일자  null
# 3429    20240106  7호선  까치울       1       0  20240109   NaN
# 26898   20240213  7호선  까치울       1       0  20240216   NaN
# 39528   20240305  7호선  까치울       1       0  20240308   NaN
# 40799   20240307  7호선  까치울       1       0  20240310   NaN
# 72308   20240427  7호선  까치울       1       0  20240430   NaN
# 101889  20240614  7호선  까치울       1       0  20240617   NaN
# 116545  20240708  7호선  까치울       1       0  20240711   NaN
# 203054  20241125  7호선  까치울       1       0  20241128   NaN
# 204194  20241127  7호선  까치울       1       0  20241130   NaN
# 223938  20241229  7호선  까치울       1       0  20250101   NaN

# %%
CARD_SUBWAY_MONTH_2024[CARD_SUBWAY_MONTH_2024["역명"] == "신촌"]
# Out:
#             사용일자  노선명  역명  승차총승객수  하차총승객수      등록일자  null
# 221     20240101  경의선  신촌     257     242  20240104   NaN
# 540     20240101  2호선  신촌   17879   16927  20240104   NaN
# 747     20240102  2호선  신촌   36716   37781  20240105   NaN
# 1139    20240102  경의선  신촌    1013    1342  20240105   NaN
# 1539    20240103  경의선  신촌    1033    1355  20240106   NaN
# ...          ...  ...  ..     ...     ...       ...   ...
# 224080  20241229  경의선  신촌     258     322  20250101   NaN
# 224327  20241230  2호선  신촌   39655   39924  20250102   NaN
# 224676  20241230  경의선  신촌     898    1153  20250102   NaN
# 225094  20241231  경의선  신촌     854    1139  20250103   NaN
# 225441  20241231  2호선  신촌   39925   40879  20250103   NaN
#
# [732 rows x 7 columns]

# %%
test23
# Out:
#          역명  노선명    mean     max    min  노선개수
# 0       동대문  1호선   23812   35181  16032     2
# 1       동묘앞  1호선   21015   37417  12384     2
# 2       서울역  1호선  105211  139845  65919     2
# 3        시청  1호선   49914   74556  17937     2
# 4       신설동  1호선   26842   37009   9983     2
# ..      ...  ...     ...     ...    ...   ...
# 313   종합운동장  9호선    9845   15620   2730     2
# 314  중앙보훈병원  9호선   20851   29135   5508     1
# 315      증미  9호선   14372   20485   3537     1
# 316    한성백제  9호선    5735   14163   1628     1
# 317      흑석  9호선   18235   29833   5437     1
#
# [318 rows x 6 columns]

# %%
1-9호선 통합본(1)

# %%
total1 = pd.read_csv("./data/metro/data/1-9호선 통합본(1).csv")

# %%
total1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 318 entries, 0 to 317
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   역명         318 non-null    object
#  1   노선명        318 non-null    object
#  2   mean       318 non-null    int64
#  3   max        318 non-null    int64
#  4   min        318 non-null    int64
#  5   노선개수       318 non-null    int64
#  6   대합실면적      279 non-null    float64
#  7   승강장면적      279 non-null    float64
#  8   지하상가 개수    211 non-null    float64
#  9   역내편의점 개수   318 non-null    float64
#  10  화장실개수      308 non-null    float64
#  11  에스컬레이터 대수  292 non-null    float64
#  12  엘리베이터 대수   292 non-null    float64
#  13  자전거보관소 대수  318 non-null    float64
#  14  물품보관함 개수   263 non-null    float64
#  15  소화기 대수     307 non-null    object
#  16  스마트도서관 개수  318 non-null    float64
# dtypes: float64(10), int64(4), object(3)
# memory usage: 42.4+ KB

# %%
total1
# Out:
#          역명  노선명    mean     max    min  노선개수   대합실면적   승강장면적  지하상가 개수  \
# 0       동대문  1호선   23812   35181  16032     2  3400.0  2090.0      1.0
# 1       동묘앞  1호선   21015   37417  12384     2  5700.0  4194.0      1.0
# 2       서울역  1호선  105211  139845  65919     2  8725.0  2080.0      1.0
# 3        시청  1호선   49914   74556  17937     2  6863.0  3784.0      6.0
# 4       신설동  1호선   26842   37009   9983     2  4164.0  3076.0      NaN
# ..      ...  ...     ...     ...    ...   ...     ...     ...      ...
# 313   종합운동장  9호선    9845   15620   2730     2     NaN     NaN      2.0
# 314  중앙보훈병원  9호선   20851   29135   5508     1     NaN     NaN      1.0
# 315      증미  9호선   14372   20485   3537     1     NaN     NaN      NaN
# 316    한성백제  9호선    5735   14163   1628     1     NaN     NaN      NaN
# 317      흑석  9호선   18235   29833   5437     1     NaN     NaN      NaN
#
#      역내편의점 개수  화장실개수  에스컬레이터 대수  엘리베이터 대수  자전거보관소 대수  물품보관함 개수 소화기 대수  \
# ...
